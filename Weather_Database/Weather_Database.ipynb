# %%
import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd 
from datetime import datetime
from config import weather_api_key

# %%
# Generate 2000 random latitudes and longitudes, and zip them as a list of tuples
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities=[]

#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 735

# %%
# Starting URL for weather map API call.
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 ==0 and i>=50):
        set_count += 1
        record_count = 1
        
    #Create endpoint url for each city.
    city_url = url + "&q=" + city
        
    #log the url,record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
        
    #Add 1 to the record count.
    record_count += 1
        
    #Run an API request for each of the cities.
    try:
         #Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
        #Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            
        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                             "Lat": city_lat,
                             "Lng": city_lng,
                             "Current Description": city_description,
                             "Max Temp": city_max_temp,
                             "Humidity": city_humidity,
                             "Cloudiness": city_clouds,
                             "Wind Speed": city_wind,
                             "Country": city_country,
                             "Date": city_date})
        
    #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
#Indicate the data loading is complete.
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | vangaindrano
# Processing Record 4 of Set 1 | hofn
# Processing Record 5 of Set 1 | saint-augustin
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | malakal
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | chimore
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | ciudad bolivar
# Processing Record 14 of Set 1 | bambous virieux
# Processing Record 15 of Set 1 | gasa
# Processing Record 16 of Set 1 | lebu
# Processing Record 17 of Set 1 | pauini
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 1 | iqaluit
# Processing Record 21 of Set 1 | baijiantan
# Processing Record 22 of Set 1 | nieves
# Processing Record 23 of Set 1 | leningradskiy
# Processing Record 24 of Set 1 | srednekolymsk
# Processing Record 25 of Set 1 | tolaga bay
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | fevralsk
# City not found. Skipping...
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | saint-philippe
# Processing Record 30 of Set 1 | port elizabeth
# Processing Record 31 of Set 1 | cody
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | georgetown
# Processing Record 35 of Set 1 | sobolevo
# Processing Record 36 of Set 1 | kavieng
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | nyurba
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | saskylakh
# Processing Record 41 of Set 1 | torbay
# Processing Record 42 of Set 1 | longyearbyen
# Processing Record 43 of Set 1 | adana
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 1 | ilulissat
# Processing Record 47 of Set 1 | puerto ayora
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | victoria
# Processing Record 50 of Set 1 | provideniya
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | brae
# Processing Record 3 of Set 2 | buala
# Processing Record 4 of Set 2 | severo-kurilsk
# Processing Record 5 of Set 2 | ponta do sol
# Processing Record 6 of Set 2 | nome
# Processing Record 7 of Set 2 | anadyr
# Processing Record 8 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 2 | tonota
# Processing Record 10 of Set 2 | ipilan
# Processing Record 11 of Set 2 | osmena
# Processing Record 12 of Set 2 | luanda
# Processing Record 13 of Set 2 | hirara
# Processing Record 14 of Set 2 | fantino
# Processing Record 15 of Set 2 | bol
# Processing Record 16 of Set 2 | san lazaro
# Processing Record 17 of Set 2 | auki
# Processing Record 18 of Set 2 | harqalah
# Processing Record 19 of Set 2 | chulman
# Processing Record 20 of Set 2 | moranbah
# Processing Record 21 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 2 | qaanaaq
# Processing Record 23 of Set 2 | saint-joseph
# Processing Record 24 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 2 | bengkulu
# Processing Record 26 of Set 2 | kodiak
# Processing Record 27 of Set 2 | barentu
# Processing Record 28 of Set 2 | skelleftea
# Processing Record 29 of Set 2 | broken hill
# Processing Record 30 of Set 2 | kaeo
# Processing Record 31 of Set 2 | new norfolk
# Processing Record 32 of Set 2 | dickinson
# Processing Record 33 of Set 2 | clyde river
# Processing Record 34 of Set 2 | ponta delgada
# Processing Record 35 of Set 2 | lagoa
# Processing Record 36 of Set 2 | coburg
# Processing Record 37 of Set 2 | hirosaki
# Processing Record 38 of Set 2 | ancud
# Processing Record 39 of Set 2 | saldanha
# Processing Record 40 of Set 2 | carnarvon
# Processing Record 41 of Set 2 | tasiilaq
# Processing Record 42 of Set 2 | kruisfontein
# Processing Record 43 of Set 2 | arraial do cabo
# Processing Record 44 of Set 2 | balikpapan
# Processing Record 45 of Set 2 | guadalajara
# Processing Record 46 of Set 2 | rocha
# Processing Record 47 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 2 | chuy
# Processing Record 49 of Set 2 | mahebourg
# Processing Record 50 of Set 2 | namatanai
# Processing Record 1 of Set 3 | nagyvenyim
# Processing Record 2 of Set 3 | pirgos
# Processing Record 3 of Set 3 | babu
# Processing Record 4 of Set 3 | oum hadjer
# Processing Record 5 of Set 3 | la asuncion
# Processing Record 6 of Set 3 | dikson
# Processing Record 7 of Set 3 | sitka
# Processing Record 8 of Set 3 | mizdah
# Processing Record 9 of Set 3 | narsaq
# Processing Record 10 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 3 | mwinilunga
# Processing Record 12 of Set 3 | khatanga
# Processing Record 13 of Set 3 | maragogi
# Processing Record 14 of Set 3 | hilo
# Processing Record 15 of Set 3 | barrow
# Processing Record 16 of Set 3 | baglung
# Processing Record 17 of Set 3 | sfantu gheorghe
# Processing Record 18 of Set 3 | henties bay
# Processing Record 19 of Set 3 | kachiry
# Processing Record 20 of Set 3 | pevek
# Processing Record 21 of Set 3 | lavrentiya
# Processing Record 22 of Set 3 | massakory
# Processing Record 23 of Set 3 | marawi
# Processing Record 24 of Set 3 | los llanos de aridane
# Processing Record 25 of Set 3 | sturgeon bay
# Processing Record 26 of Set 3 | boca do acre
# Processing Record 27 of Set 3 | tiksi
# Processing Record 28 of Set 3 | spornoye
# Processing Record 29 of Set 3 | dudinka
# Processing Record 30 of Set 3 | araouane
# Processing Record 31 of Set 3 | luderitz
# Processing Record 32 of Set 3 | tsaratanana
# Processing Record 33 of Set 3 | kapaa
# Processing Record 34 of Set 3 | ribeira grande
# Processing Record 35 of Set 3 | bilibino
# Processing Record 36 of Set 3 | constitucion
# Processing Record 37 of Set 3 | nueva italia de ruiz
# Processing Record 38 of Set 3 | nevel
# Processing Record 39 of Set 3 | sundargarh
# Processing Record 40 of Set 3 | okha
# Processing Record 41 of Set 3 | nikolskoye
# Processing Record 42 of Set 3 | cayenne
# Processing Record 43 of Set 3 | kerki
# City not found. Skipping...
# Processing Record 44 of Set 3 | bohuslav
# Processing Record 45 of Set 3 | talnakh
# Processing Record 46 of Set 3 | port hardy
# Processing Record 47 of Set 3 | kutum
# Processing Record 48 of Set 3 | san cristobal
# Processing Record 49 of Set 3 | warwick
# Processing Record 50 of Set 3 | margate
# Processing Record 1 of Set 4 | bandarbeyla
# Processing Record 2 of Set 4 | souillac
# Processing Record 3 of Set 4 | chokurdakh
# Processing Record 4 of Set 4 | turukhansk
# Processing Record 5 of Set 4 | qabis
# City not found. Skipping...
# Processing Record 6 of Set 4 | bayanday
# Processing Record 7 of Set 4 | klaksvik
# Processing Record 8 of Set 4 | komsomolskiy
# Processing Record 9 of Set 4 | zeya
# Processing Record 10 of Set 4 | villazon
# Processing Record 11 of Set 4 | buraydah
# Processing Record 12 of Set 4 | antofagasta
# Processing Record 13 of Set 4 | ambunti
# Processing Record 14 of Set 4 | ulaanbaatar
# Processing Record 15 of Set 4 | port macquarie
# Processing Record 16 of Set 4 | binga
# Processing Record 17 of Set 4 | orcopampa
# Processing Record 18 of Set 4 | avera
# Processing Record 19 of Set 4 | bahia blanca
# Processing Record 20 of Set 4 | airai
# Processing Record 21 of Set 4 | otradinskiy
# City not found. Skipping...
# Processing Record 22 of Set 4 | dilla
# Processing Record 23 of Set 4 | upernavik
# Processing Record 24 of Set 4 | juybar
# Processing Record 25 of Set 4 | caravelas
# Processing Record 26 of Set 4 | the valley
# Processing Record 27 of Set 4 | siderno
# Processing Record 28 of Set 4 | okato
# Processing Record 29 of Set 4 | tura
# Processing Record 30 of Set 4 | avarua
# Processing Record 31 of Set 4 | kharsawan
# Processing Record 32 of Set 4 | thompson
# Processing Record 33 of Set 4 | tuktoyaktuk
# Processing Record 34 of Set 4 | moba
# Processing Record 35 of Set 4 | murakami
# Processing Record 36 of Set 4 | asau
# Processing Record 37 of Set 4 | mar del plata
# Processing Record 38 of Set 4 | antalaha
# Processing Record 39 of Set 4 | skjervoy
# Processing Record 40 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 4 | liverpool
# Processing Record 42 of Set 4 | bluff
# Processing Record 43 of Set 4 | egvekinot
# Processing Record 44 of Set 4 | east london
# Processing Record 45 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 4 | nadym
# Processing Record 49 of Set 4 | balkanabat
# Processing Record 50 of Set 4 | fairbanks
# Processing Record 1 of Set 5 | conversion
# Processing Record 2 of Set 5 | faya
# Processing Record 3 of Set 5 | port hawkesbury
# Processing Record 4 of Set 5 | salalah
# Processing Record 5 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 5 | kochi
# Processing Record 7 of Set 5 | tutoia
# Processing Record 8 of Set 5 | acarau
# Processing Record 9 of Set 5 | el balyana
# City not found. Skipping...
# Processing Record 10 of Set 5 | cockburn town
# Processing Record 11 of Set 5 | katsuura
# Processing Record 12 of Set 5 | tromso
# Processing Record 13 of Set 5 | tilichiki
# Processing Record 14 of Set 5 | fortuna
# Processing Record 15 of Set 5 | delta del tigre
# Processing Record 16 of Set 5 | shakhtinsk
# Processing Record 17 of Set 5 | diego de almagro
# Processing Record 18 of Set 5 | rameswaram
# Processing Record 19 of Set 5 | crab hill
# City not found. Skipping...
# Processing Record 20 of Set 5 | isangel
# Processing Record 21 of Set 5 | yagodnoye
# Processing Record 22 of Set 5 | straumen
# Processing Record 23 of Set 5 | faanui
# Processing Record 24 of Set 5 | hazorasp
# Processing Record 25 of Set 5 | ust-kuyga
# Processing Record 26 of Set 5 | flin flon
# Processing Record 27 of Set 5 | cabo san lucas
# Processing Record 28 of Set 5 | hermanus
# Processing Record 29 of Set 5 | murdochville
# Processing Record 30 of Set 5 | samarai
# Processing Record 31 of Set 5 | broome
# Processing Record 32 of Set 5 | haines junction
# Processing Record 33 of Set 5 | beloha
# Processing Record 34 of Set 5 | quarai
# Processing Record 35 of Set 5 | namtsy
# Processing Record 36 of Set 5 | mogok
# Processing Record 37 of Set 5 | burica
# City not found. Skipping...
# Processing Record 38 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 5 | yaan
# Processing Record 40 of Set 5 | bilma
# Processing Record 41 of Set 5 | castro
# Processing Record 42 of Set 5 | kristiansund
# Processing Record 43 of Set 5 | tabou
# Processing Record 44 of Set 5 | westpunt
# City not found. Skipping...
# Processing Record 45 of Set 5 | pocone
# Processing Record 46 of Set 5 | chuzhou
# Processing Record 47 of Set 5 | norman wells
# Processing Record 48 of Set 5 | puerto maldonado
# Processing Record 49 of Set 5 | chau doc
# Processing Record 50 of Set 5 | megion
# Processing Record 1 of Set 6 | mazamari
# Processing Record 2 of Set 6 | dwarka
# Processing Record 3 of Set 6 | miastko
# Processing Record 4 of Set 6 | omsukchan
# Processing Record 5 of Set 6 | swan river
# Processing Record 6 of Set 6 | olean
# Processing Record 7 of Set 6 | cherskiy
# Processing Record 8 of Set 6 | itambacuri
# Processing Record 9 of Set 6 | alofi
# Processing Record 10 of Set 6 | uruzgan
# Processing Record 11 of Set 6 | lorengau
# Processing Record 12 of Set 6 | maarianhamina
# Processing Record 13 of Set 6 | povolzhskiy
# Processing Record 14 of Set 6 | maldonado
# Processing Record 15 of Set 6 | arman
# Processing Record 16 of Set 6 | khani
# Processing Record 17 of Set 6 | lesosibirsk
# Processing Record 18 of Set 6 | shancheng
# Processing Record 19 of Set 6 | urumqi
# Processing Record 20 of Set 6 | imeni poliny osipenko
# Processing Record 21 of Set 6 | tadine
# Processing Record 22 of Set 6 | springdale
# Processing Record 23 of Set 6 | lashio
# Processing Record 24 of Set 6 | ostrovnoy
# Processing Record 25 of Set 6 | esperance
# Processing Record 26 of Set 6 | new richmond
# Processing Record 27 of Set 6 | muravlenko
# Processing Record 28 of Set 6 | aklavik
# Processing Record 29 of Set 6 | skibbereen
# Processing Record 30 of Set 6 | nantucket
# Processing Record 31 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 32 of Set 6 | vila
# Processing Record 33 of Set 6 | tucumcari
# Processing Record 34 of Set 6 | tezu
# Processing Record 35 of Set 6 | mount isa
# Processing Record 36 of Set 6 | ilinskiy
# Processing Record 37 of Set 6 | rockland
# Processing Record 38 of Set 6 | terenos
# Processing Record 39 of Set 6 | lingao
# Processing Record 40 of Set 6 | bemidji
# Processing Record 41 of Set 6 | teya
# Processing Record 42 of Set 6 | bethel
# Processing Record 43 of Set 6 | altea
# Processing Record 44 of Set 6 | gravdal
# Processing Record 45 of Set 6 | heihe
# Processing Record 46 of Set 6 | evensk
# Processing Record 47 of Set 6 | byron bay
# Processing Record 48 of Set 6 | dunedin
# Processing Record 49 of Set 6 | alice springs
# Processing Record 50 of Set 6 | veraval
# Processing Record 1 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 2 of Set 7 | puttur
# Processing Record 3 of Set 7 | davila
# Processing Record 4 of Set 7 | saint-pierre
# Processing Record 5 of Set 7 | lichinga
# Processing Record 6 of Set 7 | bereda
# Processing Record 7 of Set 7 | kholtoson
# Processing Record 8 of Set 7 | hamilton
# Processing Record 9 of Set 7 | orje
# Processing Record 10 of Set 7 | salina
# Processing Record 11 of Set 7 | erzin
# Processing Record 12 of Set 7 | taoudenni
# Processing Record 13 of Set 7 | yeppoon
# Processing Record 14 of Set 7 | santa marta
# Processing Record 15 of Set 7 | grand gaube
# Processing Record 16 of Set 7 | hasaki
# Processing Record 17 of Set 7 | jalu
# Processing Record 18 of Set 7 | caiaponia
# Processing Record 19 of Set 7 | naze
# Processing Record 20 of Set 7 | hervey bay
# Processing Record 21 of Set 7 | aykhal
# Processing Record 22 of Set 7 | aldan
# Processing Record 23 of Set 7 | port blair
# Processing Record 24 of Set 7 | awjilah
# Processing Record 25 of Set 7 | xacmaz
# Processing Record 26 of Set 7 | nobeoka
# Processing Record 27 of Set 7 | gayny
# Processing Record 28 of Set 7 | moose factory
# Processing Record 29 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 30 of Set 7 | taramangalam
# Processing Record 31 of Set 7 | lichtenburg
# Processing Record 32 of Set 7 | kamenka
# Processing Record 33 of Set 7 | ngaoundere
# Processing Record 34 of Set 7 | puertollano
# Processing Record 35 of Set 7 | rapid valley
# Processing Record 36 of Set 7 | zyryanka
# Processing Record 37 of Set 7 | dzilam gonzalez
# Processing Record 38 of Set 7 | carutapera
# Processing Record 39 of Set 7 | kholodnyy
# Processing Record 40 of Set 7 | chernushka
# Processing Record 41 of Set 7 | te anau
# Processing Record 42 of Set 7 | howard springs
# Processing Record 43 of Set 7 | abashiri
# Processing Record 44 of Set 7 | inhambane
# Processing Record 45 of Set 7 | ginda
# Processing Record 46 of Set 7 | saqqez
# Processing Record 47 of Set 7 | baoro
# Processing Record 48 of Set 7 | genc
# Processing Record 49 of Set 7 | llanes
# Processing Record 50 of Set 7 | santa rosa
# Processing Record 1 of Set 8 | barcelos
# Processing Record 2 of Set 8 | luganville
# Processing Record 3 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 4 of Set 8 | sainte-anne-des-monts
# Processing Record 5 of Set 8 | gweta
# Processing Record 6 of Set 8 | cidreira
# Processing Record 7 of Set 8 | sayat
# Processing Record 8 of Set 8 | robertsport
# Processing Record 9 of Set 8 | keroka
# Processing Record 10 of Set 8 | progreso
# Processing Record 11 of Set 8 | prainha
# Processing Record 12 of Set 8 | yambio
# Processing Record 13 of Set 8 | thap khlo
# Processing Record 14 of Set 8 | ridgecrest
# Processing Record 15 of Set 8 | camacha
# Processing Record 16 of Set 8 | champerico
# Processing Record 17 of Set 8 | moosomin
# Processing Record 18 of Set 8 | laranjeiras do sul
# Processing Record 19 of Set 8 | pozo colorado
# Processing Record 20 of Set 8 | charagua
# Processing Record 21 of Set 8 | nanortalik
# Processing Record 22 of Set 8 | tarrafal
# Processing Record 23 of Set 8 | istok
# Processing Record 24 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 8 | kerteh
# City not found. Skipping...
# Processing Record 26 of Set 8 | rio de janeiro
# Processing Record 27 of Set 8 | khvorostyanka
# Processing Record 28 of Set 8 | torrington
# Processing Record 29 of Set 8 | santa cruz de tenerife
# Processing Record 30 of Set 8 | savelugu
# Processing Record 31 of Set 8 | moen
# Processing Record 32 of Set 8 | ust-nera
# Processing Record 33 of Set 8 | yarmouth
# Processing Record 34 of Set 8 | dongsheng
# Processing Record 35 of Set 8 | russell
# Processing Record 36 of Set 8 | fort nelson
# Processing Record 37 of Set 8 | tautira
# Processing Record 38 of Set 8 | ishigaki
# Processing Record 39 of Set 8 | sovetskaya gavan
# Processing Record 40 of Set 8 | san patricio
# Processing Record 41 of Set 8 | bubaque
# Processing Record 42 of Set 8 | rosetta
# Processing Record 43 of Set 8 | talagang
# Processing Record 44 of Set 8 | pacific grove
# Processing Record 45 of Set 8 | rundu
# Processing Record 46 of Set 8 | atar
# Processing Record 47 of Set 8 | novoshakhtinsk
# Processing Record 48 of Set 8 | macusani
# Processing Record 49 of Set 8 | nizhniy odes
# Processing Record 50 of Set 8 | havre-saint-pierre
# Processing Record 1 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 9 | la orilla
# Processing Record 3 of Set 9 | krasnyy kholm
# Processing Record 4 of Set 9 | padang
# Processing Record 5 of Set 9 | ozinki
# Processing Record 6 of Set 9 | shingu
# Processing Record 7 of Set 9 | kushima
# Processing Record 8 of Set 9 | jumla
# Processing Record 9 of Set 9 | darnah
# Processing Record 10 of Set 9 | college
# Processing Record 11 of Set 9 | churumuco
# City not found. Skipping...
# Processing Record 12 of Set 9 | ayotzintepec
# Processing Record 13 of Set 9 | hobyo
# Processing Record 14 of Set 9 | sevlievo
# Processing Record 15 of Set 9 | saint anthony
# Processing Record 16 of Set 9 | nemuro
# Processing Record 17 of Set 9 | lamu
# Processing Record 18 of Set 9 | shahrud
# Processing Record 19 of Set 9 | angra
# City not found. Skipping...
# Processing Record 20 of Set 9 | jiblah
# Processing Record 21 of Set 9 | whitehorse
# Processing Record 22 of Set 9 | touros
# Processing Record 23 of Set 9 | necochea
# Processing Record 24 of Set 9 | faribault
# Processing Record 25 of Set 9 | bathsheba
# Processing Record 26 of Set 9 | acapulco
# Processing Record 27 of Set 9 | atambua
# Processing Record 28 of Set 9 | mount gambier
# Processing Record 29 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 9 | seryshevo
# Processing Record 31 of Set 9 | kyrylivka
# Processing Record 32 of Set 9 | teknaf
# Processing Record 33 of Set 9 | gopalpur
# Processing Record 34 of Set 9 | omaruru
# Processing Record 35 of Set 9 | herat
# Processing Record 36 of Set 9 | sembakung
# Processing Record 37 of Set 9 | boyolangu
# Processing Record 38 of Set 9 | totolapan
# Processing Record 39 of Set 9 | togur
# Processing Record 40 of Set 9 | poyarkovo
# Processing Record 41 of Set 9 | pedernales
# Processing Record 42 of Set 9 | batagay
# Processing Record 43 of Set 9 | acolla
# Processing Record 44 of Set 9 | sur
# Processing Record 45 of Set 9 | port keats
# Processing Record 46 of Set 9 | murray bridge
# Processing Record 47 of Set 9 | guerrero negro
# Processing Record 48 of Set 9 | kipini
# Processing Record 49 of Set 9 | skotterud
# Processing Record 50 of Set 9 | husavik
# Processing Record 1 of Set 10 | benghazi
# Processing Record 2 of Set 10 | nieuw amsterdam
# Processing Record 3 of Set 10 | saint george
# Processing Record 4 of Set 10 | kayes
# Processing Record 5 of Set 10 | nishihara
# Processing Record 6 of Set 10 | moron
# Processing Record 7 of Set 10 | devils lake
# Processing Record 8 of Set 10 | tokmak
# Processing Record 9 of Set 10 | nuuk
# Processing Record 10 of Set 10 | manzhouli
# Processing Record 11 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 10 | maridi
# Processing Record 13 of Set 10 | zapolyarnyy
# Processing Record 14 of Set 10 | dingle
# Processing Record 15 of Set 10 | yemelyanovo
# Processing Record 16 of Set 10 | aizawl
# Processing Record 17 of Set 10 | lasa
# Processing Record 18 of Set 10 | cartagena del chaira
# Processing Record 19 of Set 10 | chumikan
# Processing Record 20 of Set 10 | chicama
# Processing Record 21 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 22 of Set 10 | westport
# Processing Record 23 of Set 10 | preobrazheniye
# Processing Record 24 of Set 10 | lompoc
# Processing Record 25 of Set 10 | placido de castro
# Processing Record 26 of Set 10 | lumsden
# Processing Record 27 of Set 10 | tanda
# Processing Record 28 of Set 10 | korla
# Processing Record 29 of Set 10 | sicamous
# Processing Record 30 of Set 10 | san pedro
# Processing Record 31 of Set 10 | tapejara
# Processing Record 32 of Set 10 | hokitika
# Processing Record 33 of Set 10 | meybod
# Processing Record 34 of Set 10 | bunbury
# Processing Record 35 of Set 10 | sakaiminato
# Processing Record 36 of Set 10 | ahipara
# Processing Record 37 of Set 10 | guaratinga
# Processing Record 38 of Set 10 | ialibu
# Processing Record 39 of Set 10 | guajara-mirim
# City not found. Skipping...
# Processing Record 40 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 41 of Set 10 | salinopolis
# Processing Record 42 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 44 of Set 10 | saint-georges
# Processing Record 45 of Set 10 | shenzhen
# Processing Record 46 of Set 10 | manokwari
# Processing Record 47 of Set 10 | chabahar
# Processing Record 48 of Set 10 | podor
# Processing Record 49 of Set 10 | yulara
# Processing Record 50 of Set 10 | ponoka
# Processing Record 1 of Set 11 | nyazepetrovsk
# Processing Record 2 of Set 11 | ha tinh
# Processing Record 3 of Set 11 | meadow lake
# Processing Record 4 of Set 11 | morrope
# Processing Record 5 of Set 11 | bosaso
# Processing Record 6 of Set 11 | trat
# Processing Record 7 of Set 11 | kulhudhuffushi
# Processing Record 8 of Set 11 | beringovskiy
# Processing Record 9 of Set 11 | highland park
# Processing Record 10 of Set 11 | agnibilekrou
# Processing Record 11 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 11 | nador
# Processing Record 13 of Set 11 | verkhnevilyuysk
# Processing Record 14 of Set 11 | opuwo
# Processing Record 15 of Set 11 | mahenge
# Processing Record 16 of Set 11 | coquimbo
# Processing Record 17 of Set 11 | waingapu
# Processing Record 18 of Set 11 | agustin codazzi
# Processing Record 19 of Set 11 | eureka
# Processing Record 20 of Set 11 | laguna
# Processing Record 21 of Set 11 | sao joao
# Processing Record 22 of Set 11 | raga
# Processing Record 23 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 24 of Set 11 | amatlan
# City not found. Skipping...
# Processing Record 25 of Set 11 | tuatapere
# Processing Record 26 of Set 11 | knysna
# Processing Record 27 of Set 11 | hibbing
# Processing Record 28 of Set 11 | paris
# Processing Record 29 of Set 11 | marsh harbour
# Processing Record 30 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 31 of Set 11 | chernyshevskiy
# Processing Record 32 of Set 11 | naryan-mar
# Processing Record 33 of Set 11 | mount pleasant
# Processing Record 34 of Set 11 | trinidad
# Processing Record 35 of Set 11 | udachnyy
# Processing Record 36 of Set 11 | pisco
# Processing Record 37 of Set 11 | longford
# Processing Record 38 of Set 11 | tarauaca
# Processing Record 39 of Set 11 | magadan
# Processing Record 40 of Set 11 | angoram
# Processing Record 41 of Set 11 | baykit
# Processing Record 42 of Set 11 | nelson bay
# Processing Record 43 of Set 11 | puerto leguizamo
# Processing Record 44 of Set 11 | pangnirtung
# Processing Record 45 of Set 11 | koslan
# Processing Record 46 of Set 11 | hambantota
# Processing Record 47 of Set 11 | bowen
# Processing Record 48 of Set 11 | mecca
# Processing Record 49 of Set 11 | rawson
# Processing Record 50 of Set 11 | sangar
# Processing Record 1 of Set 12 | alexandria
# Processing Record 2 of Set 12 | anar darreh
# City not found. Skipping...
# Processing Record 3 of Set 12 | back mountain
# Processing Record 4 of Set 12 | batemans bay
# Processing Record 5 of Set 12 | biak
# Processing Record 6 of Set 12 | makokou
# Processing Record 7 of Set 12 | grand-santi
# Processing Record 8 of Set 12 | dakar
# Processing Record 9 of Set 12 | olavarria
# Processing Record 10 of Set 12 | sao felix do xingu
# Processing Record 11 of Set 12 | kununurra
# Processing Record 12 of Set 12 | katobu
# Processing Record 13 of Set 12 | jutai
# Processing Record 14 of Set 12 | flic en flac
# Processing Record 15 of Set 12 | adrar
# Processing Record 16 of Set 12 | bismarck
# Processing Record 17 of Set 12 | hay river
# Processing Record 18 of Set 12 | celestun
# Processing Record 19 of Set 12 | roma
# Processing Record 20 of Set 12 | sambava
# Processing Record 21 of Set 12 | matamoros
# Processing Record 22 of Set 12 | sokolo
# Processing Record 23 of Set 12 | vaitape
# Processing Record 24 of Set 12 | itarema
# Processing Record 25 of Set 12 | bonavista
# Processing Record 26 of Set 12 | rehoboth
# Processing Record 27 of Set 12 | mulege
# Processing Record 28 of Set 12 | vila velha
# Processing Record 29 of Set 12 | zlatograd
# Processing Record 30 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 12 | san vicente
# Processing Record 32 of Set 12 | mao
# Processing Record 33 of Set 12 | umm lajj
# Processing Record 34 of Set 12 | tatishchevo
# Processing Record 35 of Set 12 | hit
# Processing Record 36 of Set 12 | tingo maria
# Processing Record 37 of Set 12 | kaitangata
# Processing Record 38 of Set 12 | zitlala
# Processing Record 39 of Set 12 | barabai
# Processing Record 40 of Set 12 | suntar
# Processing Record 41 of Set 12 | black river
# Processing Record 42 of Set 12 | kungurtug
# Processing Record 43 of Set 12 | vao
# Processing Record 44 of Set 12 | bara
# Processing Record 45 of Set 12 | liman
# Processing Record 46 of Set 12 | along
# Processing Record 47 of Set 12 | linjiang
# Processing Record 48 of Set 12 | havoysund
# Processing Record 49 of Set 12 | djambala
# Processing Record 50 of Set 12 | puerto escondido
# Processing Record 1 of Set 13 | kalmunai
# Processing Record 2 of Set 13 | ende
# Processing Record 3 of Set 13 | panaba
# Processing Record 4 of Set 13 | karratha
# Processing Record 5 of Set 13 | valparaiso
# Processing Record 6 of Set 13 | vardo
# Processing Record 7 of Set 13 | kozulka
# Processing Record 8 of Set 13 | oranjemund
# Processing Record 9 of Set 13 | lalin
# Processing Record 10 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 11 of Set 13 | invermere
# Processing Record 12 of Set 13 | pulsano
# Processing Record 13 of Set 13 | maniitsoq
# Processing Record 14 of Set 13 | khilok
# Processing Record 15 of Set 13 | taltal
# Processing Record 16 of Set 13 | kargasok
# Processing Record 17 of Set 13 | los chiles
# Processing Record 18 of Set 13 | nalut
# Processing Record 19 of Set 13 | manzil bu ruqaybah
# City not found. Skipping...
# Processing Record 20 of Set 13 | shiraoi
# Processing Record 21 of Set 13 | mahanje
# Processing Record 22 of Set 13 | sumenep
# Processing Record 23 of Set 13 | sept-iles
# Processing Record 24 of Set 13 | breytovo
# Processing Record 25 of Set 13 | santa cruz
# Processing Record 26 of Set 13 | dnipryany
# Processing Record 27 of Set 13 | mercedes
# Processing Record 28 of Set 13 | somogyvar
# Processing Record 29 of Set 13 | northam
# Processing Record 30 of Set 13 | virginia beach
# Processing Record 31 of Set 13 | novi iskar
# Processing Record 32 of Set 13 | daru
# Processing Record 33 of Set 13 | barhi
# Processing Record 34 of Set 13 | abu zabad
# Processing Record 35 of Set 13 | tabriz
# Processing Record 36 of Set 13 | muzhi
# Processing Record 37 of Set 13 | lundazi
# Processing Record 38 of Set 13 | mari-turek
# Processing Record 39 of Set 13 | zunyi
# Processing Record 40 of Set 13 | pareora
# Processing Record 41 of Set 13 | shaki
# Processing Record 42 of Set 13 | areosa
# Processing Record 43 of Set 13 | tongren
# Processing Record 44 of Set 13 | apex
# Processing Record 45 of Set 13 | takoradi
# Processing Record 46 of Set 13 | seminole
# Processing Record 47 of Set 13 | zhanatas
# City not found. Skipping...
# Processing Record 48 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 49 of Set 13 | nouadhibou
# Processing Record 50 of Set 13 | west bay
# Processing Record 1 of Set 14 | rongcheng
# Processing Record 2 of Set 14 | slobodskoy
# Processing Record 3 of Set 14 | najran
# Processing Record 4 of Set 14 | boa vista
# Processing Record 5 of Set 14 | zhigansk
# Processing Record 6 of Set 14 | seymchan
# Processing Record 7 of Set 14 | bumba
# Processing Record 8 of Set 14 | saint-francois
# Processing Record 9 of Set 14 | wanlaweyn
# Processing Record 10 of Set 14 | maymyo
# Processing Record 11 of Set 14 | honningsvag
# Processing Record 12 of Set 14 | nauen
# Processing Record 13 of Set 14 | vestmannaeyjar
# Processing Record 14 of Set 14 | george
# Processing Record 15 of Set 14 | paamiut
# Processing Record 16 of Set 14 | haverfordwest
# Processing Record 17 of Set 14 | maltahohe
# Processing Record 18 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 14 | yumen
# Processing Record 20 of Set 14 | gorno-altaysk
# Processing Record 21 of Set 14 | quatre cocos
# Processing Record 22 of Set 14 | doume
# Processing Record 23 of Set 14 | kuusamo
# Processing Record 24 of Set 14 | zile
# Processing Record 25 of Set 14 | matay
# Processing Record 26 of Set 14 | maseru
# Processing Record 27 of Set 14 | jizan
# Processing Record 28 of Set 14 | nizhniy tsasuchey
# Processing Record 29 of Set 14 | namibe
# Processing Record 30 of Set 14 | andenes
# Processing Record 31 of Set 14 | wagga wagga
# Processing Record 32 of Set 14 | yar-sale
# Processing Record 33 of Set 14 | mamallapuram
# Processing Record 34 of Set 14 | kiama
# Processing Record 35 of Set 14 | tuntum
# Processing Record 36 of Set 14 | san rafael
# Processing Record 37 of Set 14 | katherine
# Processing Record 38 of Set 14 | murska sobota
# Processing Record 39 of Set 14 | umarkot
# Processing Record 40 of Set 14 | asyut
# Processing Record 41 of Set 14 | trairi
# Processing Record 42 of Set 14 | kizukuri
# Processing Record 43 of Set 14 | marmande
# Processing Record 44 of Set 14 | vad
# Processing Record 45 of Set 14 | churapcha
# Processing Record 46 of Set 14 | ashland
# Processing Record 47 of Set 14 | zharkent
# Processing Record 48 of Set 14 | londoko
# Processing Record 49 of Set 14 | cordoba
# Processing Record 50 of Set 14 | waipawa
# Processing Record 1 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 15 | lima
# Processing Record 3 of Set 15 | abu dhabi
# Processing Record 4 of Set 15 | praya
# Processing Record 5 of Set 15 | southbridge
# Processing Record 6 of Set 15 | topolovgrad
# Processing Record 7 of Set 15 | san andres
# Processing Record 8 of Set 15 | mugla
# Processing Record 9 of Set 15 | palanga
# Processing Record 10 of Set 15 | pergamino
# Processing Record 11 of Set 15 | vanimo
# Processing Record 12 of Set 15 | casa nova
# Processing Record 13 of Set 15 | chingirlau
# Processing Record 14 of Set 15 | lemon tree passage
# Processing Record 15 of Set 15 | la ronge
# Processing Record 16 of Set 15 | humaita
# Processing Record 17 of Set 15 | nouakchott
# Processing Record 18 of Set 15 | lere
# Processing Record 19 of Set 15 | deep river
# Processing Record 20 of Set 15 | anito
# Processing Record 21 of Set 15 | yarada
# Processing Record 22 of Set 15 | bayburt
# Processing Record 23 of Set 15 | ambon
# Processing Record 24 of Set 15 | badiraguato
# Processing Record 25 of Set 15 | rio gallegos
# Processing Record 26 of Set 15 | svetlyy
# Processing Record 27 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 28 of Set 15 | cururupu
# Processing Record 29 of Set 15 | nargana
# Processing Record 30 of Set 15 | sao filipe
# Processing Record 31 of Set 15 | sar-e pul
# Processing Record 32 of Set 15 | christchurch
# Processing Record 33 of Set 15 | roald
# Processing Record 34 of Set 15 | simplicio mendes
# Processing Record 35 of Set 15 | ballina
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
#Convert the array of dictionaries to a panda dataframe
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0          Albany      US  2021-11-24 18:11:14  42.6001  -73.9662     41.67
# 1           Vaini      TO  2021-11-24 18:15:20 -21.2000 -175.2000     71.76
# 2    Vangaindrano      MG  2021-11-24 18:15:20 -23.3500   47.6000     74.89
# 3            Hofn      IS  2021-11-24 18:15:21  64.2539  -15.2082     30.22
# 4  Saint-Augustin      CA  2021-11-24 18:15:21  51.2260  -58.6502     45.36
# 5      Bredasdorp      ZA  2021-11-24 18:15:22 -34.5322   20.0403     63.28
# 6         Malakal      SS  2021-11-24 18:15:22   9.5334   31.6605     84.47
# 7         Rikitea      PF  2021-11-24 18:15:23 -23.1203 -134.9692     76.64
# 8         Chimore      BO  2021-11-24 18:15:23 -16.9833  -65.1333     82.83
# 9          Atuona      PF  2021-11-24 18:15:24  -9.8000 -139.0333     77.22
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        48           2        1.01           clear sky
# 1       100          40        2.30    scattered clouds
# 2        95          86        5.17          light rain
# 3        51          40       25.32    scattered clouds
# 4        98         100       13.22     overcast clouds
# 5        69           0       15.99           clear sky
# 6        29          31        7.05    scattered clouds
# 7        75         100       14.54     overcast clouds
# 8        71         100        3.78     overcast clouds
# 9        80          73       12.71          light rain

# %%
city_data_df.to_csv(path_or_buf='WeatherPy_Database.csv', index_label='City_ID')
