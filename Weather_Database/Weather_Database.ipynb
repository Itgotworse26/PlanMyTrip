# %%
import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd 
from datetime import datetime
from config import weather_api_key

# %%
# Generate 2000 random latitudes and longitudes, and zip them as a list of tuples
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities=[]

#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Starting URL for weather map API call.
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 ==0 and i>=50):
        set_count += 1
        record_count = 1
        
    #Create endpoint url for each city.
    city_url = url + "&q=" + city
        
    #log the url,record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
        
    #Add 1 to the record count.
    record_count += 1
        
    #Run an API request for each of the cities.
    try:
         #Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
        #Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            
        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                             "Lat": city_lat,
                             "Lng": city_lng,
                             "Current Description": city_description,
                             "Max Temp": city_max_temp,
                             "Humidity": city_humidity,
                             "Cloudiness": city_clouds,
                             "Wind Speed": city_wind,
                             "Country": city_country,
                             "Date": city_date})
        
    #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
#Indicate the data loading is complete.
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | palu
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | sao sebastiao
# Processing Record 8 of Set 1 | felidhoo
# City not found. Skipping...
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | wewak
# Processing Record 11 of Set 1 | okhotsk
# Processing Record 12 of Set 1 | vostok
# Processing Record 13 of Set 1 | nanortalik
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 1 | avera
# Processing Record 17 of Set 1 | faya
# Processing Record 18 of Set 1 | coihaique
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | ahipara
# Processing Record 22 of Set 1 | mayo
# Processing Record 23 of Set 1 | high level
# Processing Record 24 of Set 1 | kavieng
# Processing Record 25 of Set 1 | hami
# Processing Record 26 of Set 1 | hithadhoo
# Processing Record 27 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 1 | moissala
# Processing Record 29 of Set 1 | ancud
# Processing Record 30 of Set 1 | stornoway
# Processing Record 31 of Set 1 | kirakira
# Processing Record 32 of Set 1 | freeport
# Processing Record 33 of Set 1 | port lincoln
# Processing Record 34 of Set 1 | shache
# Processing Record 35 of Set 1 | port elizabeth
# Processing Record 36 of Set 1 | beian
# Processing Record 37 of Set 1 | kaili
# Processing Record 38 of Set 1 | chupa
# Processing Record 39 of Set 1 | pakruojis
# Processing Record 40 of Set 1 | mahebourg
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 43 of Set 1 | chuy
# Processing Record 44 of Set 1 | jabiru
# City not found. Skipping...
# Processing Record 45 of Set 1 | bethel
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | qaanaaq
# Processing Record 48 of Set 1 | bredasdorp
# Processing Record 49 of Set 1 | dikson
# Processing Record 50 of Set 1 | sayyan
# Processing Record 1 of Set 2 | victoria
# Processing Record 2 of Set 2 | north bend
# Processing Record 3 of Set 2 | broken hill
# Processing Record 4 of Set 2 | samarai
# Processing Record 5 of Set 2 | papagaios
# Processing Record 6 of Set 2 | catuday
# Processing Record 7 of Set 2 | lavrentiya
# Processing Record 8 of Set 2 | acapulco
# Processing Record 9 of Set 2 | tasiilaq
# Processing Record 10 of Set 2 | altay
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | saint anthony
# Processing Record 14 of Set 2 | aklavik
# Processing Record 15 of Set 2 | pirapozinho
# Processing Record 16 of Set 2 | lata
# Processing Record 17 of Set 2 | new norfolk
# Processing Record 18 of Set 2 | alofi
# Processing Record 19 of Set 2 | yulara
# Processing Record 20 of Set 2 | tiksi
# Processing Record 21 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 2 | haines junction
# Processing Record 23 of Set 2 | oranjemund
# Processing Record 24 of Set 2 | hilo
# Processing Record 25 of Set 2 | castro
# Processing Record 26 of Set 2 | lagoa
# Processing Record 27 of Set 2 | tagusao
# Processing Record 28 of Set 2 | albany
# Processing Record 29 of Set 2 | san patricio
# Processing Record 30 of Set 2 | faanui
# Processing Record 31 of Set 2 | puerto ayora
# Processing Record 32 of Set 2 | beaverlodge
# Processing Record 33 of Set 2 | fortuna
# Processing Record 34 of Set 2 | vanimo
# Processing Record 35 of Set 2 | pagudpud
# Processing Record 36 of Set 2 | maragogi
# Processing Record 37 of Set 2 | ponta do sol
# Processing Record 38 of Set 2 | tuatapere
# Processing Record 39 of Set 2 | morehead
# Processing Record 40 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 2 | moncton
# Processing Record 42 of Set 2 | severo-kurilsk
# Processing Record 43 of Set 2 | saint-philippe
# Processing Record 44 of Set 2 | cape town
# Processing Record 45 of Set 2 | auburn
# Processing Record 46 of Set 2 | jefferson city
# Processing Record 47 of Set 2 | isangel
# Processing Record 48 of Set 2 | mount isa
# Processing Record 49 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 50 of Set 2 | khatanga
# Processing Record 1 of Set 3 | bambous virieux
# Processing Record 2 of Set 3 | devils lake
# Processing Record 3 of Set 3 | souillac
# Processing Record 4 of Set 3 | laguna
# Processing Record 5 of Set 3 | cherskiy
# Processing Record 6 of Set 3 | kahului
# Processing Record 7 of Set 3 | torbay
# Processing Record 8 of Set 3 | riyadh
# Processing Record 9 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 3 | atuona
# Processing Record 11 of Set 3 | yar-sale
# Processing Record 12 of Set 3 | tezu
# Processing Record 13 of Set 3 | chokurdakh
# Processing Record 14 of Set 3 | upernavik
# Processing Record 15 of Set 3 | kaitangata
# Processing Record 16 of Set 3 | necochea
# Processing Record 17 of Set 3 | marawi
# Processing Record 18 of Set 3 | xining
# Processing Record 19 of Set 3 | trincomalee
# Processing Record 20 of Set 3 | brae
# Processing Record 21 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 3 | impfondo
# Processing Record 24 of Set 3 | hvammstangi
# City not found. Skipping...
# Processing Record 25 of Set 3 | henties bay
# Processing Record 26 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 27 of Set 3 | kodiak
# Processing Record 28 of Set 3 | broome
# Processing Record 29 of Set 3 | hualmay
# Processing Record 30 of Set 3 | hamilton
# Processing Record 31 of Set 3 | hanzhong
# Processing Record 32 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 3 | pak chong
# Processing Record 34 of Set 3 | nikolskoye
# Processing Record 35 of Set 3 | boa vista
# Processing Record 36 of Set 3 | qaqortoq
# Processing Record 37 of Set 3 | rangpur
# Processing Record 38 of Set 3 | ust-kuyga
# Processing Record 39 of Set 3 | xuddur
# Processing Record 40 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 3 | stettler
# Processing Record 42 of Set 3 | beringovskiy
# Processing Record 43 of Set 3 | barrow
# Processing Record 44 of Set 3 | mhango
# Processing Record 45 of Set 3 | merauke
# Processing Record 46 of Set 3 | butaritari
# Processing Record 47 of Set 3 | leningradskiy
# Processing Record 48 of Set 3 | siniscola
# Processing Record 49 of Set 3 | thompson
# Processing Record 50 of Set 3 | krasnovishersk
# Processing Record 1 of Set 4 | sao miguel do guama
# Processing Record 2 of Set 4 | oriximina
# Processing Record 3 of Set 4 | vaini
# Processing Record 4 of Set 4 | airai
# Processing Record 5 of Set 4 | georgetown
# Processing Record 6 of Set 4 | saskylakh
# Processing Record 7 of Set 4 | mar del plata
# Processing Record 8 of Set 4 | hofn
# Processing Record 9 of Set 4 | port hedland
# Processing Record 10 of Set 4 | bengkulu
# Processing Record 11 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 4 | margate
# Processing Record 13 of Set 4 | gornopravdinsk
# Processing Record 14 of Set 4 | iwaki
# Processing Record 15 of Set 4 | ballina
# Processing Record 16 of Set 4 | arraial do cabo
# Processing Record 17 of Set 4 | klaksvik
# Processing Record 18 of Set 4 | lasa
# Processing Record 19 of Set 4 | marzuq
# Processing Record 20 of Set 4 | cervo
# Processing Record 21 of Set 4 | dengfeng
# Processing Record 22 of Set 4 | cascais
# Processing Record 23 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 24 of Set 4 | ilulissat
# Processing Record 25 of Set 4 | plettenberg bay
# Processing Record 26 of Set 4 | kirensk
# Processing Record 27 of Set 4 | bitung
# Processing Record 28 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 4 | kirkcudbright
# Processing Record 30 of Set 4 | narsaq
# Processing Record 31 of Set 4 | lompoc
# Processing Record 32 of Set 4 | olinda
# Processing Record 33 of Set 4 | dunedin
# Processing Record 34 of Set 4 | constitucion
# Processing Record 35 of Set 4 | atlantic beach
# Processing Record 36 of Set 4 | podosinovets
# Processing Record 37 of Set 4 | yining
# Processing Record 38 of Set 4 | lewistown
# Processing Record 39 of Set 4 | esperance
# Processing Record 40 of Set 4 | ribeira grande
# Processing Record 41 of Set 4 | zachary
# Processing Record 42 of Set 4 | iqaluit
# Processing Record 43 of Set 4 | pangkalanbuun
# Processing Record 44 of Set 4 | fairbanks
# Processing Record 45 of Set 4 | huarmey
# Processing Record 46 of Set 4 | gizo
# Processing Record 47 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 48 of Set 4 | anuchino
# Processing Record 49 of Set 4 | susangerd
# Processing Record 50 of Set 4 | olafsvik
# Processing Record 1 of Set 5 | hasaki
# Processing Record 2 of Set 5 | kushiro
# Processing Record 3 of Set 5 | khormuj
# City not found. Skipping...
# Processing Record 4 of Set 5 | grand gaube
# Processing Record 5 of Set 5 | verkhnevilyuysk
# Processing Record 6 of Set 5 | egvekinot
# Processing Record 7 of Set 5 | antofagasta
# Processing Record 8 of Set 5 | orel-izumrud
# Processing Record 9 of Set 5 | valdivia
# Processing Record 10 of Set 5 | taltal
# Processing Record 11 of Set 5 | blackfoot
# Processing Record 12 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 13 of Set 5 | arani
# Processing Record 14 of Set 5 | lorengau
# Processing Record 15 of Set 5 | antigonish
# Processing Record 16 of Set 5 | klyuchi
# Processing Record 17 of Set 5 | rio gallegos
# Processing Record 18 of Set 5 | sibolga
# Processing Record 19 of Set 5 | tuktoyaktuk
# Processing Record 20 of Set 5 | carnarvon
# Processing Record 21 of Set 5 | luganville
# Processing Record 22 of Set 5 | tarakan
# Processing Record 23 of Set 5 | two hills
# Processing Record 24 of Set 5 | bagan
# Processing Record 25 of Set 5 | rio grande
# Processing Record 26 of Set 5 | sora
# Processing Record 27 of Set 5 | port macquarie
# Processing Record 28 of Set 5 | salalah
# Processing Record 29 of Set 5 | turukhansk
# Processing Record 30 of Set 5 | rexburg
# Processing Record 31 of Set 5 | palotina
# Processing Record 32 of Set 5 | longyearbyen
# Processing Record 33 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 34 of Set 5 | walvis bay
# Processing Record 35 of Set 5 | saint george
# Processing Record 36 of Set 5 | boysun
# Processing Record 37 of Set 5 | hovd
# Processing Record 38 of Set 5 | tamandare
# Processing Record 39 of Set 5 | berlevag
# Processing Record 40 of Set 5 | baruun-urt
# Processing Record 41 of Set 5 | shenjiamen
# Processing Record 42 of Set 5 | bowen
# Processing Record 43 of Set 5 | east london
# Processing Record 44 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 45 of Set 5 | caravelas
# Processing Record 46 of Set 5 | pevek
# Processing Record 47 of Set 5 | yumen
# Processing Record 48 of Set 5 | kimamba
# Processing Record 49 of Set 5 | kruisfontein
# Processing Record 50 of Set 5 | bandar-e lengeh
# Processing Record 1 of Set 6 | pueblo
# Processing Record 2 of Set 6 | west wendover
# Processing Record 3 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 4 of Set 6 | lebu
# Processing Record 5 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 6 | provideniya
# Processing Record 7 of Set 6 | parkland
# Processing Record 8 of Set 6 | havoysund
# Processing Record 9 of Set 6 | makakilo city
# Processing Record 10 of Set 6 | waingapu
# Processing Record 11 of Set 6 | marsh harbour
# Processing Record 12 of Set 6 | khandyga
# Processing Record 13 of Set 6 | cabo san lucas
# Processing Record 14 of Set 6 | andevoranto
# City not found. Skipping...
# Processing Record 15 of Set 6 | hambantota
# Processing Record 16 of Set 6 | coxim
# Processing Record 17 of Set 6 | albanel
# Processing Record 18 of Set 6 | torrington
# Processing Record 19 of Set 6 | mehamn
# Processing Record 20 of Set 6 | filadelfia
# Processing Record 21 of Set 6 | abha
# Processing Record 22 of Set 6 | luderitz
# Processing Record 23 of Set 6 | jamame
# Processing Record 24 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 6 | phan thiet
# Processing Record 26 of Set 6 | sungaipenuh
# Processing Record 27 of Set 6 | saldanha
# Processing Record 28 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 6 | tautira
# Processing Record 30 of Set 6 | sao geraldo do araguaia
# Processing Record 31 of Set 6 | sisimiut
# Processing Record 32 of Set 6 | shubarshi
# Processing Record 33 of Set 6 | nabire
# Processing Record 34 of Set 6 | valparaiso
# Processing Record 35 of Set 6 | massaguet
# Processing Record 36 of Set 6 | port hawkesbury
# Processing Record 37 of Set 6 | weihai
# Processing Record 38 of Set 6 | katsuura
# Processing Record 39 of Set 6 | key largo
# Processing Record 40 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 6 | oneonta
# Processing Record 42 of Set 6 | dong hoi
# Processing Record 43 of Set 6 | eldorado
# Processing Record 44 of Set 6 | kosugi
# Processing Record 45 of Set 6 | passage west
# Processing Record 46 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 6 | honiara
# Processing Record 48 of Set 6 | dingle
# Processing Record 49 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 6 | northam
# Processing Record 1 of Set 7 | am timan
# Processing Record 2 of Set 7 | san martin
# Processing Record 3 of Set 7 | sao filipe
# Processing Record 4 of Set 7 | sabang
# Processing Record 5 of Set 7 | sinegorye
# Processing Record 6 of Set 7 | ginda
# Processing Record 7 of Set 7 | mahuva
# Processing Record 8 of Set 7 | sidi ali
# Processing Record 9 of Set 7 | ulladulla
# Processing Record 10 of Set 7 | xai-xai
# Processing Record 11 of Set 7 | medak
# Processing Record 12 of Set 7 | buraydah
# Processing Record 13 of Set 7 | zyryanovsk
# Processing Record 14 of Set 7 | nome
# Processing Record 15 of Set 7 | korla
# Processing Record 16 of Set 7 | yarada
# Processing Record 17 of Set 7 | rudnogorsk
# Processing Record 18 of Set 7 | semnan
# Processing Record 19 of Set 7 | quelimane
# Processing Record 20 of Set 7 | edelira
# Processing Record 21 of Set 7 | lantawan
# Processing Record 22 of Set 7 | talcahuano
# Processing Record 23 of Set 7 | paamiut
# Processing Record 24 of Set 7 | zhicheng
# Processing Record 25 of Set 7 | karratha
# Processing Record 26 of Set 7 | khasan
# Processing Record 27 of Set 7 | upington
# Processing Record 28 of Set 7 | wukari
# Processing Record 29 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 7 | timmins
# Processing Record 31 of Set 7 | iquique
# Processing Record 32 of Set 7 | mount gambier
# Processing Record 33 of Set 7 | puerto leguizamo
# Processing Record 34 of Set 7 | buala
# Processing Record 35 of Set 7 | perry
# Processing Record 36 of Set 7 | alekseyevsk
# Processing Record 37 of Set 7 | kasongo
# Processing Record 38 of Set 7 | paso de los toros
# Processing Record 39 of Set 7 | alice springs
# Processing Record 40 of Set 7 | vao
# Processing Record 41 of Set 7 | saint-louis
# Processing Record 42 of Set 7 | livani
# Processing Record 43 of Set 7 | vila franca do campo
# Processing Record 44 of Set 7 | viedma
# Processing Record 45 of Set 7 | bilaspur
# Processing Record 46 of Set 7 | sao joao da barra
# Processing Record 47 of Set 7 | labuhan
# Processing Record 48 of Set 7 | skibbereen
# Processing Record 49 of Set 7 | tyrma
# Processing Record 50 of Set 7 | bure
# Processing Record 1 of Set 8 | saurimo
# Processing Record 2 of Set 8 | xinyu
# Processing Record 3 of Set 8 | kostomuksha
# Processing Record 4 of Set 8 | chimbote
# Processing Record 5 of Set 8 | hutchinson
# Processing Record 6 of Set 8 | atar
# Processing Record 7 of Set 8 | gorodishche
# Processing Record 8 of Set 8 | road town
# Processing Record 9 of Set 8 | ahuimanu
# Processing Record 10 of Set 8 | liwale
# Processing Record 11 of Set 8 | palmer
# Processing Record 12 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 8 | moranbah
# Processing Record 14 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 15 of Set 8 | jalu
# Processing Record 16 of Set 8 | wundanyi
# Processing Record 17 of Set 8 | coracora
# Processing Record 18 of Set 8 | bandarbeyla
# Processing Record 19 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 8 | leh
# Processing Record 21 of Set 8 | kavaratti
# Processing Record 22 of Set 8 | inirida
# Processing Record 23 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 8 | araouane
# Processing Record 25 of Set 8 | pietarsaari
# Processing Record 26 of Set 8 | bilibino
# Processing Record 27 of Set 8 | pacifica
# Processing Record 28 of Set 8 | oxelosund
# Processing Record 29 of Set 8 | saint-pierre
# Processing Record 30 of Set 8 | strezhevoy
# Processing Record 31 of Set 8 | yaan
# Processing Record 32 of Set 8 | camacha
# Processing Record 33 of Set 8 | nueva guinea
# Processing Record 34 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 35 of Set 8 | vestmannaeyjar
# Processing Record 36 of Set 8 | biltine
# Processing Record 37 of Set 8 | teahupoo
# Processing Record 38 of Set 8 | vilaka
# Processing Record 39 of Set 8 | padang
# Processing Record 40 of Set 8 | wattegama
# Processing Record 41 of Set 8 | angoche
# Processing Record 42 of Set 8 | kawalu
# Processing Record 43 of Set 8 | nizwa
# Processing Record 44 of Set 8 | pangnirtung
# Processing Record 45 of Set 8 | minatitlan
# Processing Record 46 of Set 8 | ha giang
# Processing Record 47 of Set 8 | srednekolymsk
# Processing Record 48 of Set 8 | itoman
# Processing Record 49 of Set 8 | nelson bay
# Processing Record 50 of Set 8 | namibe
# Processing Record 1 of Set 9 | mwense
# Processing Record 2 of Set 9 | yenagoa
# Processing Record 3 of Set 9 | jiayuguan
# Processing Record 4 of Set 9 | sheltozero
# Processing Record 5 of Set 9 | ilorin
# Processing Record 6 of Set 9 | kathu
# Processing Record 7 of Set 9 | poyarkovo
# Processing Record 8 of Set 9 | beruwala
# Processing Record 9 of Set 9 | athabasca
# Processing Record 10 of Set 9 | nemuro
# Processing Record 11 of Set 9 | agadir
# Processing Record 12 of Set 9 | capitan bado
# Processing Record 13 of Set 9 | tarko-sale
# Processing Record 14 of Set 9 | hermosillo
# Processing Record 15 of Set 9 | honningsvag
# Processing Record 16 of Set 9 | bayangol
# Processing Record 17 of Set 9 | janakpur
# Processing Record 18 of Set 9 | jizan
# Processing Record 19 of Set 9 | dzhebariki-khaya
# Processing Record 20 of Set 9 | batagay-alyta
# Processing Record 21 of Set 9 | sola
# Processing Record 22 of Set 9 | comodoro rivadavia
# Processing Record 23 of Set 9 | santa isabel do rio negro
# Processing Record 24 of Set 9 | myaundzha
# Processing Record 25 of Set 9 | taoudenni
# Processing Record 26 of Set 9 | cheyenne
# Processing Record 27 of Set 9 | guerrero negro
# Processing Record 28 of Set 9 | pisco
# Processing Record 29 of Set 9 | husavik
# Processing Record 30 of Set 9 | catia la mar
# Processing Record 31 of Set 9 | flin flon
# Processing Record 32 of Set 9 | martapura
# Processing Record 33 of Set 9 | akureyri
# Processing Record 34 of Set 9 | chake chake
# Processing Record 35 of Set 9 | songjianghe
# Processing Record 36 of Set 9 | dudinka
# Processing Record 37 of Set 9 | otane
# Processing Record 38 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 39 of Set 9 | sorland
# Processing Record 40 of Set 9 | sitka
# Processing Record 41 of Set 9 | esil
# Processing Record 42 of Set 9 | tyret pervaya
# Processing Record 43 of Set 9 | kangaatsiaq
# Processing Record 44 of Set 9 | vestmanna
# Processing Record 45 of Set 9 | ilhabela
# Processing Record 46 of Set 9 | obilnoye
# Processing Record 47 of Set 9 | jahrom
# City not found. Skipping...
# Processing Record 48 of Set 9 | tir pol
# City not found. Skipping...
# Processing Record 49 of Set 9 | vila velha
# Processing Record 50 of Set 9 | pacific grove
# Processing Record 1 of Set 10 | chissamba
# Processing Record 2 of Set 10 | douglas
# Processing Record 3 of Set 10 | kadipur
# Processing Record 4 of Set 10 | kutum
# Processing Record 5 of Set 10 | vuktyl
# Processing Record 6 of Set 10 | pa sang
# Processing Record 7 of Set 10 | grindavik
# Processing Record 8 of Set 10 | vysokogornyy
# Processing Record 9 of Set 10 | havre-saint-pierre
# Processing Record 10 of Set 10 | hay river
# Processing Record 11 of Set 10 | san ciro de acosta
# Processing Record 12 of Set 10 | ndola
# Processing Record 13 of Set 10 | buri
# Processing Record 14 of Set 10 | kununurra
# Processing Record 15 of Set 10 | bunia
# Processing Record 16 of Set 10 | shingu
# Processing Record 17 of Set 10 | pulaski
# Processing Record 18 of Set 10 | usinsk
# Processing Record 19 of Set 10 | cadillac
# Processing Record 20 of Set 10 | llangefni
# Processing Record 21 of Set 10 | mitzic
# Processing Record 22 of Set 10 | carpentras
# Processing Record 23 of Set 10 | knysna
# Processing Record 24 of Set 10 | malakal
# Processing Record 25 of Set 10 | caconda
# Processing Record 26 of Set 10 | port hardy
# Processing Record 27 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 28 of Set 10 | andros town
# Processing Record 29 of Set 10 | saint simons
# Processing Record 30 of Set 10 | mjolby
# Processing Record 31 of Set 10 | bethanien
# Processing Record 32 of Set 10 | bhum
# Processing Record 33 of Set 10 | anadyr
# Processing Record 34 of Set 10 | demyanovo
# Processing Record 35 of Set 10 | marrakesh
# Processing Record 36 of Set 10 | pontianak
# Processing Record 37 of Set 10 | komsomolskiy
# Processing Record 38 of Set 10 | sinnamary
# Processing Record 39 of Set 10 | cap malheureux
# Processing Record 40 of Set 10 | okitipupa
# Processing Record 41 of Set 10 | cayenne
# Processing Record 42 of Set 10 | boden
# Processing Record 43 of Set 10 | baghdad
# Processing Record 44 of Set 10 | taseyevo
# Processing Record 45 of Set 10 | clyde river
# Processing Record 46 of Set 10 | chicontepec
# Processing Record 47 of Set 10 | brownsville
# Processing Record 48 of Set 10 | havelock
# Processing Record 49 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 10 | sulangan
# Processing Record 1 of Set 11 | shimoda
# Processing Record 2 of Set 11 | poum
# Processing Record 3 of Set 11 | kazlu ruda
# Processing Record 4 of Set 11 | aguachica
# Processing Record 5 of Set 11 | tateyama
# Processing Record 6 of Set 11 | foam lake
# Processing Record 7 of Set 11 | garwa
# Processing Record 8 of Set 11 | bell ville
# Processing Record 9 of Set 11 | kiama
# Processing Record 10 of Set 11 | hornepayne
# Processing Record 11 of Set 11 | altamira
# Processing Record 12 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 11 | liverpool
# Processing Record 14 of Set 11 | sioux lookout
# Processing Record 15 of Set 11 | matara
# Processing Record 16 of Set 11 | mitu
# Processing Record 17 of Set 11 | bonthe
# Processing Record 18 of Set 11 | bara
# Processing Record 19 of Set 11 | fort nelson
# Processing Record 20 of Set 11 | abu dhabi
# Processing Record 21 of Set 11 | la ronge
# Processing Record 22 of Set 11 | ibra
# Processing Record 23 of Set 11 | olga
# Processing Record 24 of Set 11 | richards bay
# Processing Record 25 of Set 11 | ayr
# Processing Record 26 of Set 11 | vila do maio
# Processing Record 27 of Set 11 | ketchikan
# Processing Record 28 of Set 11 | harper
# Processing Record 29 of Set 11 | gumusyaka
# City not found. Skipping...
# Processing Record 30 of Set 11 | loandjili
# Processing Record 31 of Set 11 | mahajanga
# Processing Record 32 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 11 | nortelandia
# Processing Record 34 of Set 11 | nancha
# Processing Record 35 of Set 11 | calabozo
# Processing Record 36 of Set 11 | kurilsk
# Processing Record 37 of Set 11 | campbell river
# Processing Record 38 of Set 11 | marovoay
# Processing Record 39 of Set 11 | nizhniy kuranakh
# Processing Record 40 of Set 11 | rawlins
# Processing Record 41 of Set 11 | altamont
# Processing Record 42 of Set 11 | trairi
# Processing Record 43 of Set 11 | oktyabrskoye
# Processing Record 44 of Set 11 | maryville
# Processing Record 45 of Set 11 | portland
# Processing Record 46 of Set 11 | potam
# Processing Record 47 of Set 11 | saint-georges
# Processing Record 48 of Set 11 | praia da vitoria
# Processing Record 49 of Set 11 | geraldton
# Processing Record 50 of Set 11 | longyan
# Processing Record 1 of Set 12 | oksfjord
# Processing Record 2 of Set 12 | amapa
# Processing Record 3 of Set 12 | urumqi
# Processing Record 4 of Set 12 | melito di porto salvo
# Processing Record 5 of Set 12 | los llanos de aridane
# Processing Record 6 of Set 12 | presidente medici
# Processing Record 7 of Set 12 | sao lourenco do sul
# Processing Record 8 of Set 12 | yadrin
# Processing Record 9 of Set 12 | itarema
# Processing Record 10 of Set 12 | sistranda
# Processing Record 11 of Set 12 | tiangua
# Processing Record 12 of Set 12 | storforshei
# Processing Record 13 of Set 12 | cockburn town
# Processing Record 14 of Set 12 | muisne
# Processing Record 15 of Set 12 | anito
# Processing Record 16 of Set 12 | inuvik
# Processing Record 17 of Set 12 | bac ninh
# Processing Record 18 of Set 12 | tazovskiy
# Processing Record 19 of Set 12 | wuwei
# Processing Record 20 of Set 12 | inhambane
# Processing Record 21 of Set 12 | sibiti
# Processing Record 22 of Set 12 | puerto narino
# Processing Record 23 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 24 of Set 12 | port said
# Processing Record 25 of Set 12 | itaituba
# Processing Record 26 of Set 12 | yerbogachen
# Processing Record 27 of Set 12 | makung
# City not found. Skipping...
# Processing Record 28 of Set 12 | tessalit
# Processing Record 29 of Set 12 | rehoboth
# Processing Record 30 of Set 12 | shar
# Processing Record 31 of Set 12 | kokkola
# Processing Record 32 of Set 12 | hokitika
# Processing Record 33 of Set 12 | ayan
# Processing Record 34 of Set 12 | tura
# Processing Record 35 of Set 12 | abashiri
# Processing Record 36 of Set 12 | solnechnyy
# Processing Record 37 of Set 12 | puerto cabezas
# Processing Record 38 of Set 12 | minot
# Processing Record 39 of Set 12 | cidreira
# Processing Record 40 of Set 12 | carutapera
# Processing Record 41 of Set 12 | rensvik
# Processing Record 42 of Set 12 | barreirinhas
# Processing Record 43 of Set 12 | waslala
# Processing Record 44 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 45 of Set 12 | govindgarh
# Processing Record 46 of Set 12 | borama
# City not found. Skipping...
# Processing Record 47 of Set 12 | asau
# Processing Record 48 of Set 12 | digby
# Processing Record 49 of Set 12 | kathmandu
# Processing Record 50 of Set 12 | amla
# Processing Record 1 of Set 13 | gboko
# Processing Record 2 of Set 13 | lincoln
# Processing Record 3 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 4 of Set 13 | norman wells
# Processing Record 5 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 6 of Set 13 | west lafayette
# Processing Record 7 of Set 13 | villazon
# Processing Record 8 of Set 13 | cacu
# Processing Record 9 of Set 13 | bathsheba
# Processing Record 10 of Set 13 | pemberton
# Processing Record 11 of Set 13 | tilichiki
# Processing Record 12 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 13 of Set 13 | nishihara
# Processing Record 14 of Set 13 | nushki
# Processing Record 15 of Set 13 | muros
# Processing Record 16 of Set 13 | lugovoy
# Processing Record 17 of Set 13 | birobidzhan
# Processing Record 18 of Set 13 | simao
# Processing Record 19 of Set 13 | quime
# Processing Record 20 of Set 13 | maningrida
# Processing Record 21 of Set 13 | beisfjord
# Processing Record 22 of Set 13 | andarab
# City not found. Skipping...
# Processing Record 23 of Set 13 | bucerias
# Processing Record 24 of Set 13 | craig
# Processing Record 25 of Set 13 | rawson
# Processing Record 26 of Set 13 | senador jose porfirio
# Processing Record 27 of Set 13 | itarantim
# Processing Record 28 of Set 13 | el alto
# Processing Record 29 of Set 13 | puerto colombia
# Processing Record 30 of Set 13 | bismil
# Processing Record 31 of Set 13 | benghazi
# Processing Record 32 of Set 13 | bera
# Processing Record 33 of Set 13 | santa cruz
# Processing Record 34 of Set 13 | rosarito
# Processing Record 35 of Set 13 | mazyr
# Processing Record 36 of Set 13 | clarence town
# Processing Record 37 of Set 13 | akdepe
# Processing Record 38 of Set 13 | concepcion del uruguay
# Processing Record 39 of Set 13 | muroto
# Processing Record 40 of Set 13 | flinders
# Processing Record 41 of Set 13 | fuyang
# Processing Record 42 of Set 13 | san rafael del sur
# Processing Record 43 of Set 13 | panaba
# Processing Record 44 of Set 13 | coquimbo
# Processing Record 45 of Set 13 | luwuk
# Processing Record 46 of Set 13 | watsa
# Processing Record 47 of Set 13 | qabis
# City not found. Skipping...
# Processing Record 48 of Set 13 | carahue
# Processing Record 49 of Set 13 | longhua
# Processing Record 50 of Set 13 | lazaro cardenas
# Processing Record 1 of Set 14 | nokaneng
# Processing Record 2 of Set 14 | vardo
# Processing Record 3 of Set 14 | gotsu
# Processing Record 4 of Set 14 | nouakchott
# Processing Record 5 of Set 14 | hailar
# Processing Record 6 of Set 14 | birjand
# Processing Record 7 of Set 14 | mao
# Processing Record 8 of Set 14 | cairns
# Processing Record 9 of Set 14 | wladyslawowo
# Processing Record 10 of Set 14 | andenes
# Processing Record 11 of Set 14 | vaitape
# Processing Record 12 of Set 14 | sur
# Processing Record 13 of Set 14 | ballitoville
# Processing Record 14 of Set 14 | tongzi
# Processing Record 15 of Set 14 | nakamura
# Processing Record 16 of Set 14 | bose
# Processing Record 17 of Set 14 | scarborough
# Processing Record 18 of Set 14 | kyra
# Processing Record 19 of Set 14 | vondrozo
# Processing Record 20 of Set 14 | havre
# Processing Record 21 of Set 14 | codrington
# Processing Record 22 of Set 14 | awbari
# Processing Record 23 of Set 14 | boshan
# Processing Record 24 of Set 14 | springbok
# Processing Record 25 of Set 14 | sovetskiy
# Processing Record 26 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 27 of Set 14 | bequimao
# Processing Record 28 of Set 14 | anori
# Processing Record 29 of Set 14 | iralaya
# Processing Record 30 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 14 | illapel
# Processing Record 32 of Set 14 | pangody
# Processing Record 33 of Set 14 | chaupal
# Processing Record 34 of Set 14 | sindor
# Processing Record 35 of Set 14 | lumby
# Processing Record 36 of Set 14 | nouadhibou
# Processing Record 37 of Set 14 | kalangala
# Processing Record 38 of Set 14 | manama
# Processing Record 39 of Set 14 | morant bay
# Processing Record 40 of Set 14 | samarinda
# Processing Record 41 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 42 of Set 14 | cabedelo
# Processing Record 43 of Set 14 | wicklow
# Processing Record 44 of Set 14 | rostock
# Processing Record 45 of Set 14 | port augusta
# Processing Record 46 of Set 14 | neijiang
# Processing Record 47 of Set 14 | kanniyakumari
# Processing Record 48 of Set 14 | palm valley
# Processing Record 49 of Set 14 | barranca
# Processing Record 50 of Set 14 | aksu
# Processing Record 1 of Set 15 | ouadda
# Processing Record 2 of Set 15 | tiznit
# Processing Record 3 of Set 15 | la palma
# Processing Record 4 of Set 15 | marquette
# Processing Record 5 of Set 15 | jati
# Processing Record 6 of Set 15 | watertown
# Processing Record 7 of Set 15 | rusape
# Processing Record 8 of Set 15 | tyup
# Processing Record 9 of Set 15 | dicabisagan
# Processing Record 10 of Set 15 | north battleford
# Processing Record 11 of Set 15 | cartagena del chaira
# Processing Record 12 of Set 15 | college
# Processing Record 13 of Set 15 | kharela
# Processing Record 14 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 15 of Set 15 | chapleau
# Processing Record 16 of Set 15 | batagay
# Processing Record 17 of Set 15 | santa maria
# Processing Record 18 of Set 15 | harindanga
# Processing Record 19 of Set 15 | mountain home
# Processing Record 20 of Set 15 | mogadishu
# Processing Record 21 of Set 15 | baherden
# Processing Record 22 of Set 15 | nongan
# Processing Record 23 of Set 15 | barcelos
# Processing Record 24 of Set 15 | deputatskiy
# Processing Record 25 of Set 15 | miri
# Processing Record 26 of Set 15 | russell
# Processing Record 27 of Set 15 | lodja
# Processing Record 28 of Set 15 | sokolo
# Processing Record 29 of Set 15 | kapit
# Processing Record 30 of Set 15 | ushirombo
# Processing Record 31 of Set 15 | sydney
# Processing Record 32 of Set 15 | ixtapa
# Processing Record 33 of Set 15 | svetlogorsk
# Processing Record 34 of Set 15 | springfield
# Processing Record 35 of Set 15 | santa cruz cabralia
# Processing Record 36 of Set 15 | may pen
# Processing Record 37 of Set 15 | khalkhal
# Processing Record 38 of Set 15 | omsukchan
# Processing Record 39 of Set 15 | hobyo
# Processing Record 40 of Set 15 | smithers
# Processing Record 41 of Set 15 | shaoyang
# Processing Record 42 of Set 15 | meulaboh
# Processing Record 43 of Set 15 | grenada
# Processing Record 44 of Set 15 | gat
# Processing Record 45 of Set 15 | arai
# Processing Record 46 of Set 15 | tongliao
# Processing Record 47 of Set 15 | yinchuan
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
#Convert the array of dictionaries to a panda dataframe
city_data_df = pd.DataFrame(city_data)

new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

city_data_df["Lat"] = city_data_df["Lat"].map("{:,.2f}".format)
city_data_df["Lng"] = city_data_df["Lng"].map("{:,.2f}".format)

city_data_df.head(10)
# Out:
#             City Country                 Date     Lat      Lng  Max Temp  \
# 0    Yellowknife      CA  2021-11-25 18:49:19   62.46  -114.35      8.42
# 1        Mataura      NZ  2021-11-25 18:50:15  -46.19   168.86     57.33
# 2   Punta Arenas      CL  2021-11-25 18:50:15  -53.15   -70.92     51.91
# 3           Palu      ID  2021-11-25 18:50:16   -0.89   119.87     76.39
# 4      Jamestown      US  2021-11-25 18:47:37   42.10   -79.24     45.99
# 5        Ushuaia      AR  2021-11-25 18:45:39  -54.80   -68.30     49.62
# 6  Sao Sebastiao      BR  2021-11-25 18:50:16  -23.76   -45.41     76.93
# 7       Hermanus      ZA  2021-11-25 18:50:17  -34.42    19.23     63.81
# 8          Wewak      PG  2021-11-25 18:50:17   -3.55   143.63     77.59
# 9        Okhotsk      RU  2021-11-25 18:50:18   59.38   143.30      2.21
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        89          90       18.41          light snow
# 1        64         100        7.61          light rain
# 2        50          40       36.82    scattered clouds
# 3        94         100        2.82     overcast clouds
# 4        40          90        9.22     overcast clouds
# 5        61          75        6.91          light rain
# 6        78          17        8.37          few clouds
# 7        72           0       27.74           clear sky
# 8        89         100        2.53     overcast clouds
# 9        81          44        9.42    scattered clouds

# %%
city_data_df.to_csv(path_or_buf='WeatherPy_Database.csv', index_label='City_ID')
