# %%
import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd 
from datetime import datetime
from config import weather_api_key

# %%
# Generate 2000 random latitudes and longitudes, and zip them as a list of tuples
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities=[]

#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
# Starting URL for weather map API call.
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 ==0 and i>=50):
        set_count += 1
        record_count = 1
        
    #Create endpoint url for each city.
    city_url = url + "&q=" + city
        
    #log the url,record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
        
    #Add 1 to the record count.
    record_count += 1
        
    #Run an API request for each of the cities.
    try:
         #Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
        #Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            
        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                             "Lat": city_lat,
                             "Lng": city_lng,
                             "Current Description": city_description,
                             "Max Temp": city_max_temp,
                             "Humidity": city_humidity,
                             "Cloudiness": city_clouds,
                             "Wind Speed": city_wind,
                             "Country": city_country,
                             "Date": city_date})
        
    #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
#Indicate the data loading is complete.
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | severo-yeniseyskiy
# Processing Record 2 of Set 1 | kushmurun
# Processing Record 3 of Set 1 | palmer
# Processing Record 4 of Set 1 | khuzdar
# Processing Record 5 of Set 1 | ulladulla
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | touros
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 1 | bom jesus
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | east london
# Processing Record 13 of Set 1 | jinka
# Processing Record 14 of Set 1 | castro
# Processing Record 15 of Set 1 | vanderhoof
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | darab
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | vila velha
# Processing Record 22 of Set 1 | gushikawa
# Processing Record 23 of Set 1 | cidreira
# Processing Record 24 of Set 1 | san patricio
# Processing Record 25 of Set 1 | arraial do cabo
# Processing Record 26 of Set 1 | tuktoyaktuk
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | tevaitoa
# Processing Record 29 of Set 1 | hovd
# Processing Record 30 of Set 1 | yumen
# Processing Record 31 of Set 1 | severo-kurilsk
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | qaanaaq
# Processing Record 34 of Set 1 | sarkand
# Processing Record 35 of Set 1 | bethel
# Processing Record 36 of Set 1 | vardo
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | hasaki
# Processing Record 39 of Set 1 | provideniya
# Processing Record 40 of Set 1 | hualmay
# Processing Record 41 of Set 1 | pevek
# Processing Record 42 of Set 1 | matamoros
# Processing Record 43 of Set 1 | bachaquero
# Processing Record 44 of Set 1 | sorsk
# Processing Record 45 of Set 1 | saint-philippe
# Processing Record 46 of Set 1 | camacha
# Processing Record 47 of Set 1 | ahipara
# Processing Record 48 of Set 1 | ambilobe
# Processing Record 49 of Set 1 | longyearbyen
# Processing Record 50 of Set 1 | tasiilaq
# Processing Record 1 of Set 2 | aswan
# Processing Record 2 of Set 2 | preobrazheniye
# Processing Record 3 of Set 2 | carnarvon
# Processing Record 4 of Set 2 | hofn
# Processing Record 5 of Set 2 | tamazunchale
# Processing Record 6 of Set 2 | port alfred
# Processing Record 7 of Set 2 | angoche
# Processing Record 8 of Set 2 | dolores
# Processing Record 9 of Set 2 | troutdale
# Processing Record 10 of Set 2 | cedar city
# Processing Record 11 of Set 2 | kodiak
# Processing Record 12 of Set 2 | fort nelson
# Processing Record 13 of Set 2 | batagay
# Processing Record 14 of Set 2 | madaoua
# Processing Record 15 of Set 2 | great yarmouth
# Processing Record 16 of Set 2 | jamestown
# Processing Record 17 of Set 2 | komsomolets
# Processing Record 18 of Set 2 | havelock
# Processing Record 19 of Set 2 | tiksi
# Processing Record 20 of Set 2 | cornwall
# Processing Record 21 of Set 2 | clyde river
# Processing Record 22 of Set 2 | khatanga
# Processing Record 23 of Set 2 | san cristobal
# Processing Record 24 of Set 2 | beyneu
# Processing Record 25 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 2 | dong hoi
# Processing Record 27 of Set 2 | cabrero
# Processing Record 28 of Set 2 | labuhan
# Processing Record 29 of Set 2 | jalu
# Processing Record 30 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 2 | cape town
# Processing Record 32 of Set 2 | bluff
# Processing Record 33 of Set 2 | praia da vitoria
# Processing Record 34 of Set 2 | ribeira grande
# Processing Record 35 of Set 2 | lebu
# Processing Record 36 of Set 2 | vao
# Processing Record 37 of Set 2 | yulara
# Processing Record 38 of Set 2 | georgetown
# Processing Record 39 of Set 2 | hobart
# Processing Record 40 of Set 2 | innisfail
# Processing Record 41 of Set 2 | skara
# Processing Record 42 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 2 | tiznit
# Processing Record 44 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 2 | karpathos
# Processing Record 46 of Set 2 | busselton
# Processing Record 47 of Set 2 | malpe
# Processing Record 48 of Set 2 | hermanus
# Processing Record 49 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 2 | port augusta
# Processing Record 1 of Set 3 | avarua
# Processing Record 2 of Set 3 | los llanos de aridane
# Processing Record 3 of Set 3 | fuzhou
# Processing Record 4 of Set 3 | mahanoro
# Processing Record 5 of Set 3 | torbay
# Processing Record 6 of Set 3 | fallon
# Processing Record 7 of Set 3 | bredasdorp
# Processing Record 8 of Set 3 | airai
# Processing Record 9 of Set 3 | bambous virieux
# Processing Record 10 of Set 3 | norman wells
# Processing Record 11 of Set 3 | yambio
# Processing Record 12 of Set 3 | necochea
# Processing Record 13 of Set 3 | nome
# Processing Record 14 of Set 3 | dobrotesti
# Processing Record 15 of Set 3 | mozarlandia
# Processing Record 16 of Set 3 | nikolskoye
# Processing Record 17 of Set 3 | witu
# Processing Record 18 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 19 of Set 3 | maqrin
# City not found. Skipping...
# Processing Record 20 of Set 3 | naze
# Processing Record 21 of Set 3 | sola
# Processing Record 22 of Set 3 | narsaq
# Processing Record 23 of Set 3 | ponta do sol
# Processing Record 24 of Set 3 | poum
# Processing Record 25 of Set 3 | tual
# Processing Record 26 of Set 3 | pisco
# Processing Record 27 of Set 3 | faanui
# Processing Record 28 of Set 3 | cheuskiny
# City not found. Skipping...
# Processing Record 29 of Set 3 | roma
# Processing Record 30 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 3 | fortuna
# Processing Record 34 of Set 3 | khamgaon
# Processing Record 35 of Set 3 | galle
# Processing Record 36 of Set 3 | eyl
# Processing Record 37 of Set 3 | barcelos
# Processing Record 38 of Set 3 | oudtshoorn
# Processing Record 39 of Set 3 | upernavik
# Processing Record 40 of Set 3 | kavieng
# Processing Record 41 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 3 | tolaga bay
# Processing Record 43 of Set 3 | saint-pierre
# Processing Record 44 of Set 3 | pyinmana
# Processing Record 45 of Set 3 | sahiwal
# Processing Record 46 of Set 3 | sitka
# Processing Record 47 of Set 3 | bathsheba
# Processing Record 48 of Set 3 | ayagoz
# Processing Record 49 of Set 3 | mar del plata
# Processing Record 50 of Set 3 | melfi
# Processing Record 1 of Set 4 | grindavik
# Processing Record 2 of Set 4 | aksu
# Processing Record 3 of Set 4 | namanyere
# Processing Record 4 of Set 4 | chokurdakh
# Processing Record 5 of Set 4 | tubara
# Processing Record 6 of Set 4 | kapoeta
# Processing Record 7 of Set 4 | merauke
# Processing Record 8 of Set 4 | saravena
# Processing Record 9 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 4 | leningradskiy
# Processing Record 11 of Set 4 | chiojdu
# Processing Record 12 of Set 4 | tikrit
# Processing Record 13 of Set 4 | derzhavinsk
# Processing Record 14 of Set 4 | laguna
# Processing Record 15 of Set 4 | ancud
# Processing Record 16 of Set 4 | comodoro rivadavia
# Processing Record 17 of Set 4 | moron
# Processing Record 18 of Set 4 | vientiane
# Processing Record 19 of Set 4 | karlskoga
# Processing Record 20 of Set 4 | queenstown
# Processing Record 21 of Set 4 | alto araguaia
# Processing Record 22 of Set 4 | sambava
# Processing Record 23 of Set 4 | beira
# Processing Record 24 of Set 4 | barrow
# Processing Record 25 of Set 4 | tuatapere
# Processing Record 26 of Set 4 | sudogda
# Processing Record 27 of Set 4 | deputatskiy
# Processing Record 28 of Set 4 | hilo
# Processing Record 29 of Set 4 | wuwei
# Processing Record 30 of Set 4 | tomatlan
# Processing Record 31 of Set 4 | mount isa
# Processing Record 32 of Set 4 | komsomolskiy
# Processing Record 33 of Set 4 | jumla
# Processing Record 34 of Set 4 | qurayyat
# Processing Record 35 of Set 4 | viedma
# Processing Record 36 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 4 | uinskoye
# Processing Record 38 of Set 4 | celestun
# Processing Record 39 of Set 4 | saskylakh
# Processing Record 40 of Set 4 | nurmijarvi
# Processing Record 41 of Set 4 | yellowknife
# Processing Record 42 of Set 4 | colesberg
# Processing Record 43 of Set 4 | umm kaddadah
# Processing Record 44 of Set 4 | uk
# City not found. Skipping...
# Processing Record 45 of Set 4 | san lorenzo
# Processing Record 46 of Set 4 | the valley
# Processing Record 47 of Set 4 | marsa matruh
# Processing Record 48 of Set 4 | cayenne
# Processing Record 49 of Set 4 | smithers
# Processing Record 50 of Set 4 | kaitangata
# Processing Record 1 of Set 5 | marakkanam
# Processing Record 2 of Set 5 | bengkulu
# Processing Record 3 of Set 5 | asau
# Processing Record 4 of Set 5 | baiao
# Processing Record 5 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 5 | sao gabriel da cachoeira
# Processing Record 7 of Set 5 | trat
# Processing Record 8 of Set 5 | calabazar de sagua
# Processing Record 9 of Set 5 | banda aceh
# Processing Record 10 of Set 5 | aksarka
# Processing Record 11 of Set 5 | da nang
# Processing Record 12 of Set 5 | butaritari
# Processing Record 13 of Set 5 | port elizabeth
# Processing Record 14 of Set 5 | mocuba
# Processing Record 15 of Set 5 | sayville
# Processing Record 16 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 17 of Set 5 | husavik
# Processing Record 18 of Set 5 | westpunt
# City not found. Skipping...
# Processing Record 19 of Set 5 | kanigoro
# Processing Record 20 of Set 5 | heihe
# Processing Record 21 of Set 5 | nieuw amsterdam
# Processing Record 22 of Set 5 | saldanha
# Processing Record 23 of Set 5 | turayf
# Processing Record 24 of Set 5 | vila
# Processing Record 25 of Set 5 | natitingou
# Processing Record 26 of Set 5 | hlohovec
# Processing Record 27 of Set 5 | vuktyl
# Processing Record 28 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 5 | lompoc
# Processing Record 30 of Set 5 | krasnoyarka
# Processing Record 31 of Set 5 | mazagao
# Processing Record 32 of Set 5 | nishihara
# Processing Record 33 of Set 5 | salalah
# Processing Record 34 of Set 5 | bournemouth
# Processing Record 35 of Set 5 | rundu
# Processing Record 36 of Set 5 | sorland
# Processing Record 37 of Set 5 | latung
# Processing Record 38 of Set 5 | eureka
# Processing Record 39 of Set 5 | saint-augustin
# Processing Record 40 of Set 5 | kendari
# Processing Record 41 of Set 5 | dothan
# Processing Record 42 of Set 5 | hithadhoo
# Processing Record 43 of Set 5 | manaus
# Processing Record 44 of Set 5 | santander jimenez
# Processing Record 45 of Set 5 | rochester
# Processing Record 46 of Set 5 | alofi
# Processing Record 47 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 48 of Set 5 | lorengau
# Processing Record 49 of Set 5 | seoul
# Processing Record 50 of Set 5 | scarborough
# Processing Record 1 of Set 6 | wahiawa
# Processing Record 2 of Set 6 | kota bahru
# Processing Record 3 of Set 6 | broken hill
# Processing Record 4 of Set 6 | dikson
# Processing Record 5 of Set 6 | durban
# Processing Record 6 of Set 6 | nieves
# Processing Record 7 of Set 6 | lata
# Processing Record 8 of Set 6 | thinadhoo
# Processing Record 9 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 6 | sangar
# Processing Record 11 of Set 6 | port hardy
# Processing Record 12 of Set 6 | nova olinda do norte
# Processing Record 13 of Set 6 | castelnau-le-lez
# Processing Record 14 of Set 6 | sutysky
# Processing Record 15 of Set 6 | kruisfontein
# Processing Record 16 of Set 6 | bonavista
# Processing Record 17 of Set 6 | arlit
# Processing Record 18 of Set 6 | altay
# Processing Record 19 of Set 6 | vila franca do campo
# Processing Record 20 of Set 6 | motril
# Processing Record 21 of Set 6 | vieux-habitants
# Processing Record 22 of Set 6 | bilibino
# Processing Record 23 of Set 6 | pangnirtung
# Processing Record 24 of Set 6 | anadyr
# Processing Record 25 of Set 6 | san rafael
# Processing Record 26 of Set 6 | namibe
# Processing Record 27 of Set 6 | parry sound
# Processing Record 28 of Set 6 | salgueiro
# Processing Record 29 of Set 6 | road town
# Processing Record 30 of Set 6 | poya
# Processing Record 31 of Set 6 | khandyga
# Processing Record 32 of Set 6 | bhigvan
# Processing Record 33 of Set 6 | hohhot
# Processing Record 34 of Set 6 | manoel urbano
# Processing Record 35 of Set 6 | port hedland
# Processing Record 36 of Set 6 | platanos
# Processing Record 37 of Set 6 | inuvik
# Processing Record 38 of Set 6 | pichayevo
# Processing Record 39 of Set 6 | gua musang
# Processing Record 40 of Set 6 | los algarrobos
# Processing Record 41 of Set 6 | sibolga
# Processing Record 42 of Set 6 | saint george
# Processing Record 43 of Set 6 | dalvik
# Processing Record 44 of Set 6 | belebey
# Processing Record 45 of Set 6 | sandpoint
# Processing Record 46 of Set 6 | progreso
# Processing Record 47 of Set 6 | fomboni
# Processing Record 48 of Set 6 | swift current
# Processing Record 49 of Set 6 | alice springs
# Processing Record 50 of Set 6 | kastamonu
# Processing Record 1 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 7 | naqadeh
# Processing Record 3 of Set 7 | desaguadero
# Processing Record 4 of Set 7 | albania
# Processing Record 5 of Set 7 | abay
# Processing Record 6 of Set 7 | khetri
# Processing Record 7 of Set 7 | cheney
# Processing Record 8 of Set 7 | guerrero negro
# Processing Record 9 of Set 7 | agropoli
# Processing Record 10 of Set 7 | ostersund
# Processing Record 11 of Set 7 | jieshi
# Processing Record 12 of Set 7 | saint anthony
# Processing Record 13 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 7 | hobyo
# Processing Record 15 of Set 7 | farafangana
# Processing Record 16 of Set 7 | dunedin
# Processing Record 17 of Set 7 | biltine
# Processing Record 18 of Set 7 | zhezkazgan
# Processing Record 19 of Set 7 | ust-kulom
# Processing Record 20 of Set 7 | gubkinskiy
# Processing Record 21 of Set 7 | ballina
# Processing Record 22 of Set 7 | coihaique
# Processing Record 23 of Set 7 | bonthe
# Processing Record 24 of Set 7 | abatskoye
# Processing Record 25 of Set 7 | cherskiy
# Processing Record 26 of Set 7 | codrington
# Processing Record 27 of Set 7 | brejo santo
# Processing Record 28 of Set 7 | colac
# Processing Record 29 of Set 7 | cavalcante
# Processing Record 30 of Set 7 | magnor
# Processing Record 31 of Set 7 | karratha
# Processing Record 32 of Set 7 | youghal
# Processing Record 33 of Set 7 | troitsko-pechorsk
# Processing Record 34 of Set 7 | kathmandu
# Processing Record 35 of Set 7 | kupang
# Processing Record 36 of Set 7 | kyra
# Processing Record 37 of Set 7 | tonj
# Processing Record 38 of Set 7 | bandarbeyla
# Processing Record 39 of Set 7 | mecca
# Processing Record 40 of Set 7 | lagoa
# Processing Record 41 of Set 7 | bara
# Processing Record 42 of Set 7 | telimele
# Processing Record 43 of Set 7 | atar
# Processing Record 44 of Set 7 | lanzhou
# Processing Record 45 of Set 7 | balakhninskiy
# Processing Record 46 of Set 7 | tallahassee
# Processing Record 47 of Set 7 | payo
# Processing Record 48 of Set 7 | verkhnevilyuysk
# Processing Record 49 of Set 7 | lakes entrance
# Processing Record 50 of Set 7 | la seyne-sur-mer
# Processing Record 1 of Set 8 | walvis bay
# Processing Record 2 of Set 8 | todos santos
# Processing Record 3 of Set 8 | tiarei
# Processing Record 4 of Set 8 | mount gambier
# Processing Record 5 of Set 8 | kawalu
# Processing Record 6 of Set 8 | linxia
# Processing Record 7 of Set 8 | coahuayana
# Processing Record 8 of Set 8 | solnechnyy
# Processing Record 9 of Set 8 | college
# Processing Record 10 of Set 8 | iqaluit
# Processing Record 11 of Set 8 | kysyl-syr
# Processing Record 12 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 8 | beysehir
# Processing Record 14 of Set 8 | conakry
# Processing Record 15 of Set 8 | stykkisholmur
# Processing Record 16 of Set 8 | olinda
# Processing Record 17 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 8 | trairi
# Processing Record 19 of Set 8 | gurgan
# City not found. Skipping...
# Processing Record 20 of Set 8 | valparaiso
# Processing Record 21 of Set 8 | port-gentil
# Processing Record 22 of Set 8 | te anau
# Processing Record 23 of Set 8 | berlevag
# Processing Record 24 of Set 8 | bereda
# Processing Record 25 of Set 8 | srednekolymsk
# Processing Record 26 of Set 8 | agadez
# Processing Record 27 of Set 8 | maceio
# Processing Record 28 of Set 8 | mahebourg
# Processing Record 29 of Set 8 | geraldton
# Processing Record 30 of Set 8 | nanortalik
# Processing Record 31 of Set 8 | vikhorevka
# Processing Record 32 of Set 8 | beinamar
# Processing Record 33 of Set 8 | solwezi
# Processing Record 34 of Set 8 | evensk
# Processing Record 35 of Set 8 | ambo
# Processing Record 36 of Set 8 | manzhouli
# Processing Record 37 of Set 8 | umtata
# Processing Record 38 of Set 8 | korla
# Processing Record 39 of Set 8 | kaitong
# Processing Record 40 of Set 8 | taoudenni
# Processing Record 41 of Set 8 | namwala
# Processing Record 42 of Set 8 | raymond
# Processing Record 43 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 44 of Set 8 | boffa
# Processing Record 45 of Set 8 | mastic beach
# Processing Record 46 of Set 8 | makakilo city
# Processing Record 47 of Set 8 | kedougou
# Processing Record 48 of Set 8 | odda
# Processing Record 49 of Set 8 | voh
# Processing Record 50 of Set 8 | thompson
# Processing Record 1 of Set 9 | esperance
# Processing Record 2 of Set 9 | andevoranto
# City not found. Skipping...
# Processing Record 3 of Set 9 | bakel
# Processing Record 4 of Set 9 | andselv
# City not found. Skipping...
# Processing Record 5 of Set 9 | tromso
# Processing Record 6 of Set 9 | carmen de viboral
# Processing Record 7 of Set 9 | ribas do rio pardo
# Processing Record 8 of Set 9 | cabo san lucas
# Processing Record 9 of Set 9 | polazna
# Processing Record 10 of Set 9 | popondetta
# Processing Record 11 of Set 9 | cape canaveral
# Processing Record 12 of Set 9 | pundaguitan
# Processing Record 13 of Set 9 | prince george
# Processing Record 14 of Set 9 | high level
# Processing Record 15 of Set 9 | finschhafen
# Processing Record 16 of Set 9 | katsuura
# Processing Record 17 of Set 9 | natal
# Processing Record 18 of Set 9 | richards bay
# Processing Record 19 of Set 9 | sangin
# Processing Record 20 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 9 | ereymentau
# Processing Record 22 of Set 9 | chuy
# Processing Record 23 of Set 9 | valleyview
# Processing Record 24 of Set 9 | port macquarie
# Processing Record 25 of Set 9 | henties bay
# Processing Record 26 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 9 | etchojoa
# Processing Record 28 of Set 9 | beloha
# Processing Record 29 of Set 9 | sao filipe
# Processing Record 30 of Set 9 | kamyshla
# Processing Record 31 of Set 9 | westport
# Processing Record 32 of Set 9 | anloga
# Processing Record 33 of Set 9 | honiara
# Processing Record 34 of Set 9 | kalmunai
# Processing Record 35 of Set 9 | padang
# Processing Record 36 of Set 9 | christchurch
# Processing Record 37 of Set 9 | bambanglipuro
# Processing Record 38 of Set 9 | cascioarele
# Processing Record 39 of Set 9 | umm lajj
# Processing Record 40 of Set 9 | nichinan
# Processing Record 41 of Set 9 | broome
# Processing Record 42 of Set 9 | souillac
# Processing Record 43 of Set 9 | gazni
# City not found. Skipping...
# Processing Record 44 of Set 9 | namatanai
# Processing Record 45 of Set 9 | kalaiya
# Processing Record 46 of Set 9 | east wenatchee bench
# Processing Record 47 of Set 9 | williams lake
# Processing Record 48 of Set 9 | meulaboh
# Processing Record 49 of Set 9 | angoram
# Processing Record 50 of Set 9 | rampur
# Processing Record 1 of Set 10 | ibra
# Processing Record 2 of Set 10 | sekondi
# Processing Record 3 of Set 10 | tocopilla
# Processing Record 4 of Set 10 | ternate
# Processing Record 5 of Set 10 | kirakira
# Processing Record 6 of Set 10 | mangalam
# Processing Record 7 of Set 10 | ban nahin
# Processing Record 8 of Set 10 | ostashkov
# Processing Record 9 of Set 10 | lafayette
# Processing Record 10 of Set 10 | victoria
# Processing Record 11 of Set 10 | gevgelija
# Processing Record 12 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 13 of Set 10 | gummidipundi
# Processing Record 14 of Set 10 | selfoss
# Processing Record 15 of Set 10 | huarmey
# Processing Record 16 of Set 10 | singapore
# Processing Record 17 of Set 10 | honningsvag
# Processing Record 18 of Set 10 | dingle
# Processing Record 19 of Set 10 | felanitx
# Processing Record 20 of Set 10 | swan river
# Processing Record 21 of Set 10 | belyy yar
# Processing Record 22 of Set 10 | santa maria
# Processing Record 23 of Set 10 | hibbing
# Processing Record 24 of Set 10 | aleksandrovskoye
# Processing Record 25 of Set 10 | luderitz
# Processing Record 26 of Set 10 | burica
# City not found. Skipping...
# Processing Record 27 of Set 10 | borshchiv
# Processing Record 28 of Set 10 | isangel
# Processing Record 29 of Set 10 | margate
# Processing Record 30 of Set 10 | port lincoln
# Processing Record 31 of Set 10 | stekolnyy
# City not found. Skipping...
# Processing Record 32 of Set 10 | smoky lake
# Processing Record 33 of Set 10 | la ronge
# Processing Record 34 of Set 10 | sal rei
# Processing Record 35 of Set 10 | kanniyakumari
# Processing Record 36 of Set 10 | flinders
# Processing Record 37 of Set 10 | san jose
# Processing Record 38 of Set 10 | acari
# Processing Record 39 of Set 10 | patnagarh
# Processing Record 40 of Set 10 | scottsbluff
# Processing Record 41 of Set 10 | ambon
# Processing Record 42 of Set 10 | muroto
# Processing Record 43 of Set 10 | abha
# Processing Record 44 of Set 10 | linhares
# Processing Record 45 of Set 10 | northam
# Processing Record 46 of Set 10 | xixiang
# Processing Record 47 of Set 10 | itarema
# Processing Record 48 of Set 10 | cuamba
# Processing Record 49 of Set 10 | constitucion
# Processing Record 50 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 1 of Set 11 | raymondville
# Processing Record 2 of Set 11 | surab
# Processing Record 3 of Set 11 | nueva rosita
# Processing Record 4 of Set 11 | pathein
# Processing Record 5 of Set 11 | sur
# Processing Record 6 of Set 11 | itacoatiara
# Processing Record 7 of Set 11 | dubno
# Processing Record 8 of Set 11 | bandiagara
# Processing Record 9 of Set 11 | springfield
# Processing Record 10 of Set 11 | piacabucu
# Processing Record 11 of Set 11 | kahului
# Processing Record 12 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 11 | gari
# Processing Record 14 of Set 11 | sisimiut
# Processing Record 15 of Set 11 | lavrentiya
# Processing Record 16 of Set 11 | carikar
# City not found. Skipping...
# Processing Record 17 of Set 11 | kieta
# Processing Record 18 of Set 11 | wagar
# Processing Record 19 of Set 11 | planaltina
# Processing Record 20 of Set 11 | lazaro cardenas
# Processing Record 21 of Set 11 | tessalit
# Processing Record 22 of Set 11 | nanzhang
# Processing Record 23 of Set 11 | paramonga
# Processing Record 24 of Set 11 | campbellsville
# Processing Record 25 of Set 11 | talnakh
# Processing Record 26 of Set 11 | bang pakong
# Processing Record 27 of Set 11 | songwa
# Processing Record 28 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 29 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 30 of Set 11 | kalofer
# Processing Record 31 of Set 11 | sao miguel
# Processing Record 32 of Set 11 | gilbues
# Processing Record 33 of Set 11 | rocha
# Processing Record 34 of Set 11 | brownsville
# Processing Record 35 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 36 of Set 11 | dubovskoye
# Processing Record 37 of Set 11 | zabaykalsk
# Processing Record 38 of Set 11 | saint-francois
# Processing Record 39 of Set 11 | alta floresta
# Processing Record 40 of Set 11 | sfantu gheorghe
# Processing Record 41 of Set 11 | bud
# Processing Record 42 of Set 11 | vestmannaeyjar
# Processing Record 43 of Set 11 | lumphat
# Processing Record 44 of Set 11 | mulchen
# Processing Record 45 of Set 11 | sarangani
# Processing Record 46 of Set 11 | talcahuano
# Processing Record 47 of Set 11 | zadar
# Processing Record 48 of Set 11 | san policarpo
# Processing Record 49 of Set 11 | mundo nuevo
# Processing Record 50 of Set 11 | holme
# Processing Record 1 of Set 12 | lagos
# Processing Record 2 of Set 12 | san buenaventura
# Processing Record 3 of Set 12 | siniscola
# Processing Record 4 of Set 12 | gazli
# Processing Record 5 of Set 12 | asprovalta
# Processing Record 6 of Set 12 | vostok
# Processing Record 7 of Set 12 | buta
# Processing Record 8 of Set 12 | guozhen
# Processing Record 9 of Set 12 | wajima
# Processing Record 10 of Set 12 | hamilton
# Processing Record 11 of Set 12 | den helder
# Processing Record 12 of Set 12 | kuytun
# Processing Record 13 of Set 12 | kaseda
# Processing Record 14 of Set 12 | adwa
# Processing Record 15 of Set 12 | simplicio mendes
# Processing Record 16 of Set 12 | nouadhibou
# Processing Record 17 of Set 12 | dharchula
# Processing Record 18 of Set 12 | flin flon
# Processing Record 19 of Set 12 | concordia
# Processing Record 20 of Set 12 | nelson bay
# Processing Record 21 of Set 12 | langham
# Processing Record 22 of Set 12 | rio pardo
# Processing Record 23 of Set 12 | baracoa
# Processing Record 24 of Set 12 | igrim
# Processing Record 25 of Set 12 | beihai
# Processing Record 26 of Set 12 | manta
# Processing Record 27 of Set 12 | leesburg
# Processing Record 28 of Set 12 | san andres
# Processing Record 29 of Set 12 | batagay-alyta
# Processing Record 30 of Set 12 | greenwood
# Processing Record 31 of Set 12 | klaksvik
# Processing Record 32 of Set 12 | toul
# Processing Record 33 of Set 12 | sinnamary
# Processing Record 34 of Set 12 | corning
# Processing Record 35 of Set 12 | cimarron hills
# Processing Record 36 of Set 12 | ilulissat
# Processing Record 37 of Set 12 | carutapera
# Processing Record 38 of Set 12 | hagere hiywet
# Processing Record 39 of Set 12 | tilichiki
# Processing Record 40 of Set 12 | santa isabel do rio negro
# Processing Record 41 of Set 12 | gambela
# Processing Record 42 of Set 12 | saurimo
# Processing Record 43 of Set 12 | hue
# Processing Record 44 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 45 of Set 12 | mayo
# Processing Record 46 of Set 12 | samur
# Processing Record 47 of Set 12 | havre-saint-pierre
# Processing Record 48 of Set 12 | hareid
# Processing Record 49 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 50 of Set 12 | saint pete beach
# Processing Record 1 of Set 13 | hannibal
# Processing Record 2 of Set 13 | kavaratti
# Processing Record 3 of Set 13 | olafsvik
# Processing Record 4 of Set 13 | bartica
# Processing Record 5 of Set 13 | port blair
# Processing Record 6 of Set 13 | price
# Processing Record 7 of Set 13 | minab
# Processing Record 8 of Set 13 | kaduy
# Processing Record 9 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 10 of Set 13 | inhambane
# Processing Record 11 of Set 13 | soufriere
# Processing Record 12 of Set 13 | paltinis
# Processing Record 13 of Set 13 | shirokiy
# Processing Record 14 of Set 13 | yulin
# Processing Record 15 of Set 13 | acarau
# Processing Record 16 of Set 13 | colares
# Processing Record 17 of Set 13 | kovdor
# Processing Record 18 of Set 13 | guilin
# Processing Record 19 of Set 13 | albert
# Processing Record 20 of Set 13 | san ramon
# Processing Record 21 of Set 13 | dalbandin
# Processing Record 22 of Set 13 | kautokeino
# Processing Record 23 of Set 13 | tombouctou
# Processing Record 24 of Set 13 | eydhafushi
# Processing Record 25 of Set 13 | arman
# Processing Record 26 of Set 13 | novopavlovka
# Processing Record 27 of Set 13 | auki
# Processing Record 28 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 29 of Set 13 | adrar
# Processing Record 30 of Set 13 | byron bay
# Processing Record 31 of Set 13 | aegviidu
# Processing Record 32 of Set 13 | lopsmarka
# Processing Record 33 of Set 13 | podgornoye
# Processing Record 34 of Set 13 | san onofre
# Processing Record 35 of Set 13 | teguldet
# Processing Record 36 of Set 13 | opuwo
# Processing Record 37 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 38 of Set 13 | tazmalt
# Processing Record 39 of Set 13 | juifang
# City not found. Skipping...
# Processing Record 40 of Set 13 | datong
# Processing Record 41 of Set 13 | honavar
# Processing Record 42 of Set 13 | mogadishu
# Processing Record 43 of Set 13 | oranjemund
# Processing Record 44 of Set 13 | houston
# Processing Record 45 of Set 13 | actopan
# Processing Record 46 of Set 13 | blonduos
# City not found. Skipping...
# Processing Record 47 of Set 13 | baruun-urt
# Processing Record 48 of Set 13 | bol
# Processing Record 49 of Set 13 | balaipungut
# Processing Record 50 of Set 13 | barra patuca
# Processing Record 1 of Set 14 | kutum
# Processing Record 2 of Set 14 | marzuq
# Processing Record 3 of Set 14 | tsaratanana
# Processing Record 4 of Set 14 | maumere
# Processing Record 5 of Set 14 | feijo
# Processing Record 6 of Set 14 | manokwari
# Processing Record 7 of Set 14 | cumbum
# Processing Record 8 of Set 14 | yar-sale
# Processing Record 9 of Set 14 | ust-maya
# Processing Record 10 of Set 14 | samatau
# City not found. Skipping...
# Processing Record 11 of Set 14 | mont-dore
# Processing Record 12 of Set 14 | roald
# Processing Record 13 of Set 14 | gibsons
# Processing Record 14 of Set 14 | manggar
# Processing Record 15 of Set 14 | luocheng
# Processing Record 16 of Set 14 | kirksville
# Processing Record 17 of Set 14 | hambantota
# Processing Record 18 of Set 14 | aykhal
# Processing Record 19 of Set 14 | kibungan
# Processing Record 20 of Set 14 | mantua
# Processing Record 21 of Set 14 | stromness
# Processing Record 22 of Set 14 | businga
# Processing Record 23 of Set 14 | doembang nangbuat
# Processing Record 24 of Set 14 | edgewater
# Processing Record 25 of Set 14 | novobataysk
# Processing Record 26 of Set 14 | goure
# Processing Record 27 of Set 14 | ratnapura
# Processing Record 28 of Set 14 | mosquera
# Processing Record 29 of Set 14 | chara
# Processing Record 30 of Set 14 | marsh harbour
# Processing Record 31 of Set 14 | kismayo
# Processing Record 32 of Set 14 | egvekinot
# Processing Record 33 of Set 14 | englewood
# Processing Record 34 of Set 14 | eidfjord
# Processing Record 35 of Set 14 | fulacunda
# City not found. Skipping...
# Processing Record 36 of Set 14 | dinguiraye
# Processing Record 37 of Set 14 | hami
# Processing Record 38 of Set 14 | mayumba
# Processing Record 39 of Set 14 | cape elizabeth
# City not found. Skipping...
# Processing Record 40 of Set 14 | tecoanapa
# Processing Record 41 of Set 14 | baghdad
# Processing Record 42 of Set 14 | napier
# Processing Record 43 of Set 14 | porto nacional
# Processing Record 44 of Set 14 | kasongo-lunda
# Processing Record 45 of Set 14 | deoria
# Processing Record 46 of Set 14 | chapada dos guimaraes
# Processing Record 47 of Set 14 | nantucket
# Processing Record 48 of Set 14 | balikpapan
# Processing Record 49 of Set 14 | sassandra
# Processing Record 50 of Set 14 | constantine
# Processing Record 1 of Set 15 | hendaye
# Processing Record 2 of Set 15 | mogadouro
# Processing Record 3 of Set 15 | siderno
# Processing Record 4 of Set 15 | tarakan
# Processing Record 5 of Set 15 | huambo
# Processing Record 6 of Set 15 | kasama
# Processing Record 7 of Set 15 | nacala
# Processing Record 8 of Set 15 | crestview
# Processing Record 9 of Set 15 | buraydah
# Processing Record 10 of Set 15 | coquimbo
# Processing Record 11 of Set 15 | beringovskiy
# Processing Record 12 of Set 15 | tautira
# Processing Record 13 of Set 15 | machilipatnam
# Processing Record 14 of Set 15 | sao domingos
# Processing Record 15 of Set 15 | belaya kholunitsa
# Processing Record 16 of Set 15 | ayan
# Processing Record 17 of Set 15 | cururupu
# Processing Record 18 of Set 15 | krasnyy luch
# Processing Record 19 of Set 15 | mutsu
# Processing Record 20 of Set 15 | dabakala
# Processing Record 21 of Set 15 | ketchikan
# Processing Record 22 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 23 of Set 15 | svetlaya
# Processing Record 24 of Set 15 | morant bay
# Processing Record 25 of Set 15 | jatai
# Processing Record 26 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 27 of Set 15 | peniche
# Processing Record 28 of Set 15 | hasanabad
# Processing Record 29 of Set 15 | drayton valley
# Processing Record 30 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 31 of Set 15 | puteyets
# Processing Record 32 of Set 15 | lensk
# Processing Record 33 of Set 15 | lahan
# Processing Record 34 of Set 15 | kashima
# Processing Record 35 of Set 15 | vanimo
# Processing Record 36 of Set 15 | tambilil
# Processing Record 37 of Set 15 | lannion
# Processing Record 38 of Set 15 | san quintin
# Processing Record 39 of Set 15 | chimbote
# Processing Record 40 of Set 15 | whitehorse
# Processing Record 41 of Set 15 | brightwater
# Processing Record 42 of Set 15 | pizhanka
# Processing Record 43 of Set 15 | kuvandyk
# Processing Record 44 of Set 15 | shitanjing
# Processing Record 45 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 15 | warqla
# City not found. Skipping...
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
#Convert the array of dictionaries to a panda dataframe
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                  City Country                 Date      Lat       Lng  \
# 0  Severo-Yeniseyskiy      RU  2021-11-23 22:15:40  60.3725   93.0408
# 1           Kushmurun      KZ  2021-11-23 22:15:41  52.4503   64.6311
# 2              Palmer      US  2021-11-23 22:15:40  42.1584  -72.3287
# 3             Khuzdar      PK  2021-11-23 22:15:41  27.7384   66.6434
# 4           Ulladulla      AU  2021-11-23 22:06:42 -35.3500  150.4667
# 5             Rikitea      PF  2021-11-23 22:15:42 -23.1203 -134.9692
# 6              Touros      BR  2021-11-23 22:15:42  -5.1989  -35.4608
# 7              Albany      US  2021-11-23 22:15:43  42.6001  -73.9662
# 8           Bom Jesus      BR  2021-11-23 22:11:24  -9.0744  -44.3586
# 9             Ushuaia      AR  2021-11-23 22:15:43 -54.8000  -68.3000
#
#    Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 0     20.50        92         100        6.85          light snow
# 1     11.30        93          84        8.86       broken clouds
# 2     35.46        43          20        5.99          few clouds
# 3     58.89        30           0        5.77           clear sky
# 4     70.88        76         100        3.96          light rain
# 5     76.89        81          30       15.01    scattered clouds
# 6     81.50        79          55       15.10       broken clouds
# 7     31.26        57          12        8.01          few clouds
# 8     77.38        78          63        3.22       broken clouds
# 9     44.26        81          75        9.22          light rain

# %%
city_data_df.to_csv(path_or_buf='WeatherPy_Database.csv', index_label='City_ID')
